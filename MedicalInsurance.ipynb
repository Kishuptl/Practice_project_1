# %% [markdown]
# # Medical Cost Personal Insurance Project

# %%
# import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df = pd.read_csv('medicalinsurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# the above dataset contain numerical and categorical data. but no independent variable.

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# this dataset contain 1338 rows and 7 columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# as per above dtypes we can see there are 3 types of data( int64 ,float64 and object).

# %%
# checking nan values 

df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# as there is no nan values present in this dataset.

# %%
# now we can check heatmap

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# as per above heatmap there are no null values present.

# %%
# to get the overview of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# lets check unique values

df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df['charges'].nunique()
# Out:
# 1337

# %%
df['bmi'].nunique()
# Out:
# 548

# %%
# checking the value of each column

for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %% [markdown]
# as per above there is no blank space and no nan values.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # seperating Numerical and Categorical columns

# %%
# checking for categorical columns
categorical=[]
for i in df.dtypes.index:
    if df.dtypes[i] == 'object':
        categorical.append(i)
    print('Categorical columns :',categorical)
# Out:
# Categorical columns : []
# Categorical columns : ['sex']
# Categorical columns : ['sex']
# Categorical columns : ['sex']
# Categorical columns : ['sex', 'smoker']
# Categorical columns : ['sex', 'smoker', 'region']
# Categorical columns : ['sex', 'smoker', 'region']

# %%
# checking for numerical columns
numerical =[]
for i in df.dtypes.index:
    if df.dtypes[i] != 'object':
        numerical.append(i)
    print('Numerical columns:',numerical)
# Out:
# Numerical columns: ['age']
# Numerical columns: ['age']
# Numerical columns: ['age', 'bmi']
# Numerical columns: ['age', 'bmi', 'children']
# Numerical columns: ['age', 'bmi', 'children']
# Numerical columns: ['age', 'bmi', 'children']
# Numerical columns: ['age', 'bmi', 'children', 'charges']

# %%
# checking the number of unique values in each columns

df.nunique().to_frame('No. of unique values')
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1. Univariate analysis

# %% [markdown]
# in this we will use diffrent plot on each columns for better understanding.

# %%
# here we will use count plot as there is only 2 values ..

sns.countplot(df['smoker'])
print(df['smoker'].value_counts)
plt.show()
# Out:
# <bound method IndexOpsMixin.value_counts of 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object>

# %% [markdown]
# as per above we can see that the count of 'No smoker' is higher then the 'Yes smoker'.
# It means the its imbalanced data.

# %%
# in this we are using sountplot as there is only 2 values 

print(df['sex'].value_counts())
sns.countplot(df['sex'])
plt.show()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# in the above plot we can see the count of male and female for this insurance is almost same.

# %%
# we will use count plot as this column has on few values.

print(df['children'].value_counts())
sns.countplot(df['children'])
plt.show()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# as per the above graph we can see there are maximum people who has no children and very less people who has 5 children.

# %%
# using dist plot for age column as it has multiple values

sns.distplot(df['age'])
print(df['age'].value_counts())
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
# here we are using count plot as region has 4 values 

print(df['region'].value_counts())
sns.countplot(df['region'])
plt.show()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# as per above graph we can see that southeast region has highest number of people and remain region as almost same .

# %%
# as charges column have multiple values hence using distplot

print(df['charges'].value_counts())
sns.distplot(df['charges'])
plt.show()
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
# dist plot is used as bmi column has multiple values.

print(df['bmi'].value_counts())
sns.distplot(df['bmi'])
plt.show()
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %% [markdown]
# 2. Bivariate analysis

# %% [markdown]
# Here in this Bivariate Analysis we will do comparision between 2 columns.

# %%
# comparing smoker and sex

plt.title('comparision of column smoker and sex.')
sns.stripplot(x='smoker',y='sex',data=df)
plt.show()

# %% [markdown]
# There is no difference between the features, here both are equal in length.

# %%
# comparing smoker and bmi

plt.title('comparision between smoker and bmi.')
sns.scatterplot(x='smoker',y='bmi',data=df,hue='smoker',palette='deep')
plt.show()

# %% [markdown]
# as per above plot there is not much difference between this two.

# %%
# comparing smoker and charges

plt.title('comparision between smoker and charges')
sns.scatterplot(x='smoker',y='charges',data=df,hue='smoker',palette='bright')
plt.show()

# %% [markdown]
# as per above observation we can see that charges for insurance increases for smokers and decreases for non smokers.

# %%
# comparing age and charges

plt.title('Comparision between age and charges.')
sns.scatterplot(x='age',y='charges',data=df,hue='age',palette='deep')
plt.show()

# %% [markdown]
# the above plot shows that as age increase charges also increase.

# %%
plt.title('Compairing age and bmi.')
sns.scatterplot(x='bmi',y='age',data=df,palette='bright')
# Out:
# <AxesSubplot:title={'center':'Compairing age and bmi.'}, xlabel='bmi', ylabel='age'>

# %%
# use of catplot

sns.catplot(x='sex',y='age',data=df,palette='bright')

sns.catplot(x='bmi',y='age',data=df,palette='pastel')

sns.catplot(x='smoker',y='age',data=df,palette='husl')

sns.catplot(x='charges',y='age',data=df ,palette='flare')

# %% [markdown]
# 1. as per this plot both male and female have same age .

# %% [markdown]
# 2. in this plot both age and bmi is same .

# %% [markdown]
# 3. as per this plot smokers and non smoker are same .

# %% [markdown]
# 4. in this it show as the age increase , charges also increase.

# %% [markdown]
# 3. Multivariate Analysis

# %%
sns.pairplot(df,hue='smoker',palette='pastel')

# %% [markdown]
# 1. The above pairplot gives the pairwise relation between the dataset on basis of smokers.

# %% [markdown]
# 2. There is no linear relation but we can see some outliers

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # finding outlier

# %%
df.plot(kind='box' , subplots=True , layout=(2,6) , figsize=(15,6))
# Out:
# age            AxesSubplot(0.125,0.53;0.110714x0.35)
# sex         AxesSubplot(0.257857,0.53;0.110714x0.35)
# bmi         AxesSubplot(0.390714,0.53;0.110714x0.35)
# children    AxesSubplot(0.523571,0.53;0.110714x0.35)
# smoker      AxesSubplot(0.656429,0.53;0.110714x0.35)
# region      AxesSubplot(0.789286,0.53;0.110714x0.35)
# charges        AxesSubplot(0.125,0.11;0.110714x0.35)
# dtype: object

# %% [markdown]
# as per above plot we can see there are some outlier in bmi and charges column only and we need to remove it.

# %% [markdown]
# # removing outlier using zscore

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
z
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  0.403289  0.592496
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  1.287881  1.475201
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  1.287881  0.801132
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  1.365894  0.949586
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  1.365894  0.914914
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  1.365894  0.034353
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  0.481303  1.320300
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  1.287881  1.509411
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  0.403289  1.381121
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  1.365894  1.367233
#
# [1338 rows x 7 columns]

# %% [markdown]
# now outlier is removed .

# %%
thresold = 3
print(np.where(z>3))
# Out:
# (array([  32,   71,  116,  166,  413,  425,  438,  568,  640,  847,  877,
#         932,  937,  969,  984, 1047, 1085, 1116, 1130, 1245, 1272, 1317],
#       dtype=int64), array([3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2],
#       dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
df_new
# Out:
#       age  sex     bmi  children  smoker  region    charges
# 0      19    1  27.900         0       0       1  25.654666
# 1      18    0  33.770         1       1       0  11.994331
# 2      28    0  33.000         3       1       0  16.447599
# 3      33    0  22.705         0       1       3  28.013799
# 4      32    0  28.880         0       1       3  15.695891
# ...   ...  ...     ...       ...     ...     ...        ...
# 1333   50    0  30.970         3       1       3  21.967271
# 1334   18    1  31.920         0       1       2  13.017690
# 1335   18    1  36.850         0       1       0  11.768318
# 1336   21    1  25.800         0       1       1  12.615872
# 1337   61    1  29.070         0       0       3  30.773007
#
# [1316 rows x 7 columns]

# %%
# checking skewness

df.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker     -1.464766
# region      0.048975
# charges     0.515183
# dtype: float64

# %% [markdown]
# as we can see that there is skewness is present in children and charges column but childern column is categorical data so here dont need to remove the skewness .But need to removed skewness on charges column.

# %%
# removing skewness using cube root method

# %%
df['charges']= np.cbrt(df['charges'])

# %%
df.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker     -1.464766
# region      0.048975
# charges     0.116171
# dtype: float64

# %% [markdown]
# now skewness is removed from charges column.

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.795217
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     1.000000
# 50%      39.000000     0.000000    30.400000     1.000000     1.000000
# 75%      51.000000     1.000000    34.693750     2.000000     1.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region      charges
# count  1338.000000  1338.000000
# mean      1.455904     2.762562
# std       1.130888     0.281137
# min       0.000000     2.182140
# 25%       0.000000     2.561078
# 50%       1.000000     2.762907
# 75%       2.000000     2.944535
# max       3.000000     3.418587

# %%
sns.lmplot(x='age',y='bmi',data=df)

# %%
df.hist(bins=20, figsize=(10,10))
plt.show()

# %%
df.plot(kind='kde' , subplots=True , layout=(2,6) , figsize=(15,6))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %% [markdown]
# # Data Pre_Processing

# %% [markdown]
# As in the data set there are 3 column which has categorical data and 3 column has numerical data so now Encoding the categorical data into numerical .

# %%
# encoding sex column
df.replace({'sex':{'male':0,'female':1}},inplace=True)

# encoding smoker column
df.replace({'smoker':{'yes':0,'no':1}},inplace=True)

#encoding region
df.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}},inplace=True)

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region   charges
# 0      19    1  27.900         0       0       1  2.949322
# 1      18    0  33.770         1       1       0  2.289068
# 2      28    0  33.000         3       1       0  2.543124
# 3      33    0  22.705         0       1       3  3.037088
# 4      32    0  28.880         0       1       3  2.503775
# ...   ...  ...     ...       ...     ...     ...       ...
# 1333   50    0  30.970         3       1       3  2.800649
# 1334   18    1  31.920         0       1       2  2.352401
# 1335   18    1  36.850         0       1       0  2.274599
# 1336   21    1  25.800         0       1       1  2.327943
# 1337   61    1  29.070         0       0       3  3.133694
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %% [markdown]
# now we can see that object column is converted in to int64 columns.

# %%
# checking correlation

df_corr = df.corr()

# %%
df_corr
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469  0.025019  0.005212  0.503830
# sex       0.020856  1.000000 -0.046371 -0.017163  0.076185  0.016121 -0.013334
# bmi       0.109272 -0.046371  1.000000  0.012759 -0.003750 -0.261829  0.140623
# children  0.042469 -0.017163  0.012759  1.000000 -0.007673  0.019257  0.148572
# smoker    0.025019  0.076185 -0.003750 -0.007673  1.000000  0.053930 -0.690611
# region    0.005212  0.016121 -0.261829  0.019257  0.053930  1.000000 -0.010791
# charges   0.503830 -0.013334  0.140623  0.148572 -0.690611 -0.010791  1.000000

# %%
# checking heatmap for correlation

sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking multicollinearity

# %%
plt.figure(figsize =(10,6))
sns.heatmap(df_corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df_corr['charges'].sort_values(ascending = False)
# Out:
# charges     1.000000
# age         0.503830
# children    0.148572
# bmi         0.140623
# region     -0.010791
# sex        -0.013334
# smoker     -0.690611
# Name: charges, dtype: float64

# %% [markdown]
# here we can see the positive and negative correlation with target variable.

# %% [markdown]
# Splitting the dataset in to x and y.

# %%
x1 = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# we need only columns from x to check multicollinearity , where rows=0 and columns=1

x1.shape[1]
# Out:
# 6

# %%
y
# Out:
# 0       2.949322
# 1       2.289068
# 2       2.543124
# 3       3.037088
# 4       2.503775
#           ...
# 1333    2.800649
# 1334    2.352401
# 1335    2.274599
# 1336    2.327943
# 1337    3.133694
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# # Use of VIF for multicollinearity

# %%
import statsmodels.api as sm
from scipy import stats

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def cal_vif(x1):
    vif = pd.DataFrame()
    vif['Variables'] = x1.columns
    vif['vif factor'] = [variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
    return(vif)

cal_vif(x1)
# Out:
#   Variables  vif factor
# 0       age    8.054031
# 1       sex    1.946970
# 2       bmi   10.007692
# 3  children    1.807952
# 4    smoker    4.591597
# 5    region    2.449996

# %%
x1= df.drop(['bmi'], axis=1)

# %%
cal_vif(x1)
# Out:
#   Variables  vif factor
# 0       age   11.472108
# 1       sex    1.999618
# 2  children    1.867143
# 3    smoker    4.036699
# 4    region    2.672771
# 5   charges   15.287457

# %%
x = x1

# %%
# use of train_test_split method 

from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train , y_test = train_test_split(x,y,test_size=.2 ,random_state=2)

# %%
x_train.shape
# Out:
# (1070, 6)

# %%
x_test.shape
# Out:
# (268, 6)

# %%
y_train.shape
# Out:
# (1070,)

# %%
y_test.shape
# Out:
# (268,)

# %% [markdown]
# checking r2_score , mean_squared_error , mean_absolute_error by applying different model.

# %%
import sklearn
from sklearn.metrics import accuracy_score , r2_score , mean_squared_error , mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
pred_lr = lr.predict(x_test)
print('Linear Regression')

print('r2 score:',r2_score(y_test,pred_lr))
print('mean square error :',mean_squared_error(y_test,pred_lr))
print('mean absolute error:',mean_absolute_error(y_test,pred_lr))
print('square root error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Linear Regression
# r2 score: 1.0
# mean square error : 4.2622036968657653e-29
# mean absolute error: 5.368839701172399e-15
# square root error: 6.528555503988432e-15

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(x_train ,y_train)
pred_svr = svr.predict(x_test)
print('Support Vector Regressor')

print('r2 score',r2_score(y_test,pred_svr))
print('mean squared error :',mean_squared_error(y_test,pred_svr))
print('mean absolute error:',mean_absolute_error(y_test,pred_svr))
print(' square root error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# Support Vector Regressor
# r2 score 0.998176632046292
# mean squared error : 0.08570078607104206
# mean absolute error: 0.16722911620017009
#  square root error: 0.2927469659467747

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
pred_knr = knr.predict(x_test)
print(' KNeighborsRegressor')

print('r2 score:',r2_score(y_test,pred_knr))
print('mean squared error :',mean_squared_error(y_test,pred_knr))
print('mean absolute error:',mean_absolute_error(y_test,pred_knr))
print('square root error:',np.sqrt(mean_squared_error(y_test,pred_knr)))
# Out:
#  KNeighborsRegressor
# r2 score: 0.994951843684263
# mean squared error : 0.2372702468464297
# mean absolute error: 0.2610122881038321
# square root error: 0.4871039384427411

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train , y_train)
pred_rfr = rfr.predict(x_test)
print(' Random Foreset Regressor')

print('r2 score:',r2_score(y_test,pred_rfr))
print('mean squared error :',mean_squared_error(y_test,pred_rfr))
print('mean absolute error:',mean_absolute_error(y_test,pred_rfr))
print('mean squared root error:',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
#  Random Foreset Regressor
# r2 score: 0.9999044720526808
# mean squared error : 0.004489944095131634
# mean absolute error: 0.021522978869741277
# mean squared root error: 0.06700704511565657

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso(alpha = 0.0001)
ls.fit(x_train ,y_train)
pred_ls = ls.predict(x_test)
print(' Lasso Regressor')

print('r2 score:',r2_score(y_test,pred_ls))
print('mean square eror:',mean_squared_error(y_test,pred_ls))
print('mean absolute error:',mean_absolute_error(y_test,pred_ls))
print('square root error: ',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
#  Lasso Regressor
# r2 score: 0.9999999999929848
# mean square eror: 3.297231024752876e-10
# mean absolute error: 1.4963571784506651e-05
# square root error:  1.8158279171642e-05

# %%
from sklearn.linear_model import Ridge

# %%
rd = Ridge(alpha = 0.0001)
rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
print('Ridge Regressor')

print('r2 score :',r2_score(y_test,pred_rd))
print('mean squared error :',mean_squared_error(y_test,pred_rd))
print('mean absolute error:',mean_absolute_error(y_test,pred_rd))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge Regressor
# r2 score : 1.0
# mean squared error : 8.542322019173003e-16
# mean absolute error: 1.91143588386752e-08
# mean squared root error: 2.922725101540171e-08

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr = gbr.predict(x_test)
print('Gradient Boosting Regressor')

print('r2 score :',r2_score(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('mean absolute error:',mean_absolute_error(y_test,pred_gbr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# Gradient Boosting Regressor
# r2 score : 0.9998433815308005
# mean squared error: 0.007361282124289061
# mean absolute error: 0.045747763435664134
# mean squared root error: 0.08579791445186218

# %%
from sklearn.ensemble import BaggingRegressor

# %%
br = BaggingRegressor()
br.fit(x_train , y_train)
pred_br = br.predict(x_test)
print('Bagging Regressor')

print('r2 score:',r2_score(y_test,pred_br))
print('mean squared error :',mean_squared_error(y_test,pred_br))
print('mean absolute error:',mean_absolute_error(y_test,pred_br))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_br)))
# Out:
# Bagging Regressor
# r2 score: 0.9999112245815089
# mean squared error : 0.00417256601060378
# mean absolute error: 0.02390136367267882
# squared root error: 0.06459540239524621

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(lr ,x,y, cv=6)
print('score1:',score1)
print('score1 mean:',score1.mean())
print('score1 std',score1.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_lr)-score1.mean())*100)
# Out:
# score1: [1. 1. 1. 1. 1. 1.]
# score1 mean: 1.0
# score1 std 0.0
# Difference b/w r2 score and mean : -443821.19015487307

# %%
score2 = cross_val_score(svr,x,y,cv=6)
print('score2:',score2)
print('score2 mean:',score2.mean())
print('score std:',score2.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_svr)-score2.mean())*100)
# Out:
# score2: [0.71360348 0.68025179 0.72741402 0.76340622 0.68264898 0.60616691]
# score2 mean: 0.6955818993948988
# score std: 0.04887997748671306
# Difference b/w r2 score and mean : -439883.0516305753

# %%
score3 = cross_val_score(knr,x,y,cv=6)
print('score3:',score3)
print('score3 mean:',score3.mean())
print('score3 std:',score3.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_knr)-score3.mean())*100)
# Out:
# score3: [0.73159583 0.6462107  0.74264886 0.76041373 0.6684281  0.70338523]
# score3 mean: 0.7087804087422908
# score3 std: 0.04063250012782715
# Difference b/w r2 score and mean : -439223.02179547487

# %%
score4 = cross_val_score(rfr, x,y,cv=6)
print('score4:',score4)
print('score4 mean:',score4.mean())
print('score4 std:',score4.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_rfr)-score4.mean())*100)
# Out:
# score4: [0.99999231 0.99997276 0.99993728 0.99999115 0.99999222 0.99996479]
# score4 mean: 0.9999750843795513
# score4 std: 1.9953817526959137e-05
# Difference b/w r2 score and mean : -443758.69429042214

# %%
score5 = cross_val_score(ls,x,y,cv=5)
print('score5 :',score5)
print('score5 mean:',score5.mean())
print('score5 std:',score5.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_ls)-score5.mean())*100)
# Out:
# score5 : [0.99999761 0.99999687 0.99999775 0.99999753 0.99999677]
# score5 mean: 0.9999973065853078
# score5 std: 4.0503821938497767e-07
# Difference b/w r2 score and mean : -443820.98256201035

# %%
score6 = cross_val_score(rd,x,y,cv=6)
print('score6:',score6)
print('score6 mean:',score6.mean())
print('score6 std:',score6.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_rd)-score6.mean())*100)
# Out:
# score6: [1. 1. 1. 1. 1. 1.]
# score6 mean: 0.9999999999942916
# score6 std: 1.3850576749919326e-12
# Difference b/w r2 score and mean : -443821.18998740223

# %%
score7 = cross_val_score(gbr,x,y,cv=6)
print('score7:',score7)
print('score7 mean:',score7.mean())
print('score7 std:',score7.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_gbr)-score7.mean())*100)
# Out:
# score7: [0.99992694 0.99991649 0.99992447 0.99991734 0.99992623 0.99992882]
# score7 mean: 0.9999233798400583
# score7 std: 4.753774227766892e-06
# Difference b/w r2 score and mean : -443983.98982595635

# %%
score8 = cross_val_score(br,x,y,cv=6)
print('score8:',score8)
print('score8 mean:',score8.mean())
print('score8 std:',score8.std())
print('Difference b/w r2 score and mean :',(r2_score(y_test,pred_br)-score8.mean())*100)
# Out:
# score8: [0.99998519 0.99998172 0.99995214 0.99998325 0.99998353 0.99997331]
# score8 mean: 0.9999765236035266
# score8 std: 1.155511337848395e-05
# Difference b/w r2 score and mean : -443750.56590235635

# %% [markdown]
# as per the above result the Linear Regression has lowest std and difference between r2 score & mean score . So it is best fitting model for prediction.

# %% [markdown]
# # Finalizing the model

# %%
from sklearn.metrics import accuracy_score

# %%
final_model= GradientBoostingRegressor()
final_model.fit(x_train,y_train)
pred = final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9368\1664117131.py in <module>
#       2 final_model.fit(x_train,y_train)
#       3 pred = final_model.predict(x_test)
# ----> 4 acc = accuracy_score(y_test,pred)
#       5 print(acc*100)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#     102     # No metrics support "multiclass-multioutput" format
# ...

# %% [markdown]
# # Saving Best Model

# %%
# saving best model using .pkl

import joblib
joblib.dump(final_model,'medical_insurance.pkl')
# Out:
# ['medical_insurance.pkl']

# %%
# predicting the saved model

model = joblib.load('medical_insurance.pkl')

# prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([2.3740005 , 2.8212701 , 2.77028495, 2.28888161, 2.74316567,
#        2.61153095, 2.85503647, 2.35151966, 2.89450889, 2.68564869,
#        2.8446489 , 2.3542272 , 2.99632222, 2.18546898, 3.10378305,
#        2.86273309, 2.49265473, 2.59454029, 2.98795128, 2.35166301,
#        2.8346676 , 2.3983395 , 3.24618647, 3.04398643, 3.22272229,
#        2.79998202, 2.45295554, 2.75046751, 2.48170144, 2.44881069,
#        2.59765607, 2.5078338 , 2.57277338, 2.52511527, 2.90107097,
#        2.27528738, 3.2349675 , 3.0087356 , 3.20031167, 3.1095934 ,
#        2.34202352, 3.18722085, 2.69303123, 2.33029625, 2.66521622,
#        2.59770233, 2.78555235, 2.47336085, 2.52513804, 3.01941834,
#        2.57152209, 2.20714256, 2.96270541, 3.27779465, 2.6570674 ,
#        2.82650794, 2.3231878 , 2.67937942, 2.34957242, 3.24613627,
#        2.89657024, 2.34177742, 2.42107232, 3.27197209, 2.20714256,
#        2.83912475, 3.03298904, 2.30895694, 2.87721775, 2.69223592,
# ...

# %% [markdown]
# # checking the model given is correct result

# %%
a = np.array(y_test)
df= pd.DataFrame()
df['predicted']=prediction
df['original']=a
df
# Out:
#      predicted  original
# 0     2.374001  2.374006
# 1     2.821270  2.820230
# 2     2.770285  2.770533
# 3     2.288882  2.288165
# 4     2.743166  2.746459
# ..         ...       ...
# 263   2.288836  2.289397
# 264   2.826303  2.827913
# 265   3.134519  3.133694
# 266   2.750399  2.749433
# 267   3.065024  3.066370
#
# [268 rows x 2 columns]
