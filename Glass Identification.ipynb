# %% [markdown]
# # Glass_Identification

# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# getting dataset 

ds = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')
ds
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %% [markdown]
# some time github link doesnot works so using saved csv file.

# %%
ds = pd.read_csv('glass.csv')
ds
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %% [markdown]
# # Assigning Name to columns

# %%
# Raw dataset
files = 'glass.csv'
headers=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type']

# reading file and add headers
ds= pd.read_csv(files,header=None)
ds.columns=headers

# %%
ds
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %% [markdown]
# the above dataset contain 214 rows amd 11 columns.

# %% [markdown]
# # Now converting csv data in to dataframe.

# %%
glsdf = pd.DataFrame(data=ds)
glsdf
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %% [markdown]
# in above dataset we can see there are 214 rows and 11 columns are there out of 11 columns 1 columns is dependent .

# %%
# setting ID column as index column

glsdf.set_index('Id',inplace=True)
glsdf
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# Id
# 1    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 2    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 3    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 4    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 5    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # Performning EDA

# %%
glsdf.shape
# Out:
# (214, 10)

# %%
glsdf.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
glsdf.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
glsdf.info
# Out:
# <bound method DataFrame.info of           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# Id
# 1    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 2    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 3    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 4    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 5    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]>

# %%
glsdf.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
# this gives statistical information of the numerical columns.

# %% [markdown]
# here we can see that there is no much difference in mean and median of dataset .

# %% [markdown]
# By summarizing the data we can see there is little difference between 75% and max , hence there might be some outlier is present in dataset.

# %% [markdown]
# we can also notice the Standard Deviation , minimum values ,25% value from this describe method.

# %% [markdown]
# # Checking Null values

# %%
glsdf.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# as per above data we can see there is no null value present in this dataset.

# %%
# checking null values using heatmap

sns.heatmap(glsdf.isnull())
# Out:
# <AxesSubplot:ylabel='Id'>

# %% [markdown]
# this heatmap also shows that there is no null value present in the dataset.

# %%
# checking the number of unique  values in each column
 
glsdf.nunique().to_frame('No of unique values')
# Out:
#       No of unique values
# RI                    178
# Na                    142
# Mg                     94
# Al                    118
# Si                    133
# K                      65
# Ca                    143
# Ba                     34
# Fe                     32
# Type                    6

# %% [markdown]
# There are unique values present in each columns.

# %% [markdown]
# # Lets check Correlation

# %%
glsdf_corr=glsdf.corr()
glsdf_corr
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
# heatmap for correlation

sns.heatmap(glsdf_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1.Univariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.countplot(glsdf['RI'])
print(glsdf['RI'].value_counts())
plt.show()
# Out:
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64

# %% [markdown]
# as per above plot we can see that there are certain points it goes high.

# %%
plt.figure(figsize=(10,6))
sns.countplot(glsdf['Na'])
print(glsdf['Na'].value_counts())
plt.show()
# Out:
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na, Length: 142, dtype: int64

# %% [markdown]
# Above plot shows Sodiam is level is not same all the time.

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['Mg'])
print(glsdf['Mg'].value_counts())
plt.show()
# Out:
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64

# %% [markdown]
# Above plot show magnesium goes up for 2 times one at 0 and other at 4.

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['Al'])
print(glsdf['Al'].value_counts())
plt.show()
# Out:
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al, Length: 118, dtype: int64

# %% [markdown]
# Above plot shows that Aluminum is highest in between 1 and 2 .

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['Si'])
print(glsdf['Si'].value_counts())
plt.show()
# Out:
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# 73.11    4
#         ..
# 73.55    1
# 72.34    1
# 72.26    1
# 73.26    1
# 73.61    1
# Name: Si, Length: 133, dtype: int64

# %% [markdown]
# as per above plot Silicon is high at 73.

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['K'])
print(glsdf['K'].value_counts())
plt.show()
# Out:
# 0.00    30
# 0.57    12
# 0.56    11
# 0.60    11
# 0.58    10
#         ..
# 0.44     1
# 0.07     1
# 0.73     1
# 0.70     1
# 1.41     1
# Name: K, Length: 65, dtype: int64

# %% [markdown]
# above plot shows that Potassium is high between 0 and 1.

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['Ca'])
print(glsdf['Ca'].value_counts())
plt.show()
# Out:
# 8.03    5
# 8.43    5
# 9.57    4
# 8.79    4
# 8.44    4
#        ..
# 9.23    1
# 8.90    1
# 9.13    1
# 8.09    1
# 8.62    1
# Name: Ca, Length: 143, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(glsdf['Ba'])
print(glsdf['Ba'].value_counts())
plt.show()
# Out:
# 0.00    176
# 0.64      2
# 1.57      2
# 0.09      2
# 1.59      2
# 0.11      2
# 3.15      1
# 0.81      1
# 1.64      1
# 1.06      1
# 0.54      1
# 2.88      1
# 1.38      1
# 1.55      1
# 0.67      1
# 1.71      1
# 0.56      1
# 0.63      1
# 0.53      1
# 0.66      1
# 0.61      1
# 0.27      1
# 0.69      1
# 0.40      1
# 0.14      1
# 0.76      1
# 1.68      1
# 1.63      1
# 1.19      1
# 0.24      1
# 2.20      1
# 0.15      1
# 0.06      1
# 1.67      1
# Name: Ba, dtype: int64

# %% [markdown]
# above plot shows that Barium is high at 0 and rest all are equal .

# %%
plt.figure(figsize=(10,6))
sns.countplot(glsdf['Fe'])
print(glsdf['Fe'].value_counts())
plt.show()
# Out:
# 0.00    144
# 0.24      7
# 0.17      7
# 0.09      6
# 0.10      5
# 0.11      4
# 0.16      3
# 0.28      3
# 0.12      3
# 0.22      3
# 0.14      3
# 0.07      3
# 0.19      2
# 0.15      2
# 0.08      2
# 0.06      1
# 0.21      1
# 0.05      1
# 0.51      1
# 0.37      1
# 0.35      1
# 0.25      1
# 0.18      1
# 0.34      1
# 0.29      1
# 0.30      1
# 0.20      1
# 0.32      1
# 0.26      1
# 0.03      1
# 0.31      1
# 0.01      1
# Name: Fe, dtype: int64

# %% [markdown]
# above plot shows that iron is high at 0 level and moderate at other.

# %%
plt.figure(figsize=(10,6))
sns.distplot(glsdf['Type'])
print(glsdf['Type'].value_counts())
plt.show()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %% [markdown]
# above plot shows that type of glass is high at 2 ,medium between 6 and 8 .

# %% [markdown]
# 2. Bivariate Analysis

# %%
# comparision between RI and Na

plt.figure(figsize=(10,6))
plt.title('comparision between RI and Na')
sns.stripplot(x='RI',y='Na',data=glsdf,palette='deep')
plt.show()

# %% [markdown]
# in this plot RI and Na is almost same.

# %%
# comparision between Na and Mg

plt.figure(figsize=(10,6))
plt.title('Comparision between Na and Mg')
sns.stripplot(x='Na',y='Mg',data=glsdf,palette='bright')
plt.show()

# %% [markdown]
# in this plot we can see that potassium and magnesium is equally distributed.

# %%
# comparision between Mg and Al

plt.figure(figsize=(10,6))
plt.title('Comparision between Mg and Al')
sns.stripplot(x='Mg',y='Al',data=glsdf,palette='icefire')
plt.show()

# %% [markdown]
# in this plot aluminum and magnesium is equally distributed.

# %%
# comparision between Al and Si

plt.figure(figsize=(10,6))
plt.title('comparision between Al and Si')
sns.stripplot(x='Si',y='Al',data=glsdf,palette='bright')
plt.show()

# %%
# compariosion between Si and K

plt.figure(figsize=(10,6))
plt.title('Comparision between Si and K')
sns.scatterplot(x='K',y='Si',data=glsdf,palette='deep')
plt.show()

# %% [markdown]
# here we see that maximum of potassium and Silicon is in between 0 to 1.

# %%
# comparision between K and Ca

plt.figure(figsize=(10,6))
plt.title('comparision between K and Ca')
sns.scatterplot(x='Ca',y='K',data=glsdf,palette='bright')
plt.show()

# %%
# comparision between Ca and Ba

plt.figure(figsize=(10,6))
plt.title('comparision between Ca and Ba')
sns.scatterplot(x='Ba',y='Ca',data=glsdf,palette='deep')
plt.show()

# %%
# comparisioon between Ba and Fe

plt.figure(figsize=(10,6))
plt.title('comparision between Ba and Fe')
sns.scatterplot(x='Fe',y='Ba',data=glsdf,palette='icefire')
plt.show()

# %%
# comparision between fe and Type of glass

plt.figure(figsize=(10,6))
plt.title('comparision between Fe and Type of glass')
sns.scatterplot(x='Type',y='Fe',data=glsdf,palette='deep')
plt.show()

# %% [markdown]
# in this comparision we can see that most of value of Fe is in 1 ,2 and 7 type of glass.

# %%
# Checking Type with Na
sns.catplot(x='Type',y='Na',data=glsdf,palette='spring_r')

# checking Type with Mg
sns.catplot(x='Type',y='Mg',data=glsdf,palette='spring_r')

# checking Type with Al
sns.catplot(x='Type',y='Al',data=glsdf,palette='spring_r')

# checking Type with Si
sns.catplot(x='Type',y='Si',data=glsdf,palette='spring_r')

# checking Type with K
sns.catplot(x='Type',y='K',data=glsdf,palette='spring_r')

# %% [markdown]
# 1. In first plot we see that maximum of Sodium is in Type 1 and 2.

# %% [markdown]
# 2. In second plot we see that maximum of Magnesium is in Type 2.

# %% [markdown]
# 3. Third plot shows that Type 1 and 2 have maximum Aluminm

# %% [markdown]
# 4. as per forth plot Type 2 has maximum Silicon.

# %% [markdown]
# 5. Fifth plot shows potassium is equally scatter in all type.

# %%
# checking type of glass in RI

sns.catplot(x='RI',col='Type',data=glsdf,palette='deep',kind='count')

# %% [markdown]
# the above plot shows that maximum of RI is in type 1 and 2.

# %%
# checking Type with Na
sns.catplot(x='Na',col='Type',data=glsdf,palette='bright',kind='count')

# %% [markdown]
# above plot shows that type 1 and 2 has maximum of sodium values.

# %%
# checking Type with K
sns.catplot(x='K',col='Type',data=glsdf,palette='cividis',kind='count')

# %% [markdown]
# this plot also shows that type 1 and 2 has maximum value for Potassium.

# %% [markdown]
# 3. Multivariate Analysis

# %%
sns.pairplot(data=glsdf , hue='Type' ,palette='cividis')

# %% [markdown]
# the above plot isa pairwise relation between the columns and Type of glass.

# %% [markdown]
# # Checking Outlier

# %% [markdown]
# Checking outlier using boxplot

# %%
glsdf.plot(kind='box' , subplots=True , layout=(2,6) , figsize=(10,10))
# Out:
# RI         AxesSubplot(0.125,0.53;0.110714x0.35)
# Na      AxesSubplot(0.257857,0.53;0.110714x0.35)
# Mg      AxesSubplot(0.390714,0.53;0.110714x0.35)
# Al      AxesSubplot(0.523571,0.53;0.110714x0.35)
# Si      AxesSubplot(0.656429,0.53;0.110714x0.35)
# K       AxesSubplot(0.789286,0.53;0.110714x0.35)
# Ca         AxesSubplot(0.125,0.11;0.110714x0.35)
# Ba      AxesSubplot(0.257857,0.11;0.110714x0.35)
# Fe      AxesSubplot(0.390714,0.11;0.110714x0.35)
# Type    AxesSubplot(0.523571,0.11;0.110714x0.35)
# dtype: object

# %% [markdown]
# as per above we can see there outliers is present in almost all the columns and we need to remove it .

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(glsdf))
z
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# Id
# 1    0.872868  0.284953  1.254639  0.692442  1.127082  0.671705  0.145766
# 2    0.249333  0.591817  0.636168  0.170460  0.102319  0.026213  0.793734
# 3    0.721318  0.149933  0.601422  0.190912  0.438787  0.164533  0.828949
# 4    0.232831  0.242853  0.698710  0.310994  0.052974  0.112107  0.519052
# 5    0.312045  0.169205  0.650066  0.411375  0.555256  0.081369  0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 210  0.704815  0.898681  1.865511  2.881125  0.052974  0.640968  0.157088
# 211  0.500178  1.856097  1.865511  1.094342  0.529374  0.763919  0.392276
# 212  0.754046  1.168721  1.865511  1.154570  0.995252  0.763919  0.364103
# 213  0.612399  1.193270  1.865511  0.993960  1.241133  0.763919  0.335931
# 214  0.414363  1.009152  1.865511  1.275028  0.917606  0.763919  0.237327
#
#            Ba        Fe      Type
# Id
# 1    0.352877  0.586451  0.848275
# ...

# %%
print(np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#        131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#        188, 189, 201, 201, 203, 207, 213], dtype=int64), array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#        5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
glsdf_new = glsdf[(z<3).all(axis=1)]
glsdf_new
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# Id
# 1    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 2    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 3    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 4    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 5    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0     7
# 210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
#
# [194 rows x 10 columns]

# %%
glsdf = glsdf_new

# %% [markdown]
# now we can see the all the outlier is removed .

# %% [markdown]
# # checking Skewness

# %%
glsdf.skew()
# Out:
# RI      0.952733
# Na      0.371482
# Mg     -1.528849
# Al      0.658259
# Si     -0.425450
# K       0.303175
# Ca      1.077962
# Ba      3.188587
# Fe      1.486479
# Type    1.284007
# dtype: float64

# %% [markdown]
# here we can see there is some skewness present in the dataset .

# %% [markdown]
# # Removing Skewness

# %%
glsdf = np.cbrt(glsdf)
glsdf.skew()
# Out:
# RI      0.948045
# Na      0.240950
# Mg     -1.899050
# Al     -0.374978
# Si     -0.447904
# K      -1.307953
# Ca      0.611914
# Ba      2.207594
# Fe      0.883166
# Type    0.851675
# dtype: float64

# %% [markdown]
# now skewness is almost removed.

# %% [markdown]
# # Lets Check Correlation

# %%
glsdf.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000  0.051513  0.063437 -0.551755 -0.610009 -0.191141  0.690642
# Na    0.051513  1.000000 -0.516631  0.146868 -0.243264 -0.725002  0.013077
# Mg    0.063437 -0.516631  1.000000 -0.495639 -0.361350  0.611014 -0.389151
# Al   -0.551755  0.146868 -0.495639  1.000000  0.352401 -0.066448 -0.266408
# Si   -0.610009 -0.243264 -0.361350  0.352401  1.000000 -0.034581 -0.161181
# K    -0.191141 -0.725002  0.611014 -0.066448 -0.034581  1.000000 -0.357646
# Ca    0.690642  0.013077 -0.389151 -0.266408 -0.161181 -0.357646  1.000000
# Ba   -0.226117  0.539724 -0.651379  0.526273  0.182935 -0.485484 -0.148491
# Fe    0.016211 -0.158912  0.110677 -0.070569  0.002703  0.136253  0.013133
# Type -0.177116  0.474579 -0.739953  0.584123  0.247626 -0.550610  0.140243
#
#             Ba        Fe      Type
# RI   -0.226117  0.016211 -0.177116
# Na    0.539724 -0.158912  0.474579
# Mg   -0.651379  0.110677 -0.739953
# ...

# %%
# checking correlation using heatmap

plt.figure(figsize=(10,6))
sns.heatmap(glsdf.corr() , cmap='crest' , annot=True)
plt.show()

# %% [markdown]
# as per above heatmap we can see that the multicollinearity is present .

# %%
# Assigning x and y value 

x1 = glsdf.iloc[:,:-1]
y = glsdf.iloc[:,-1]

# %%
x1.shape
# Out:
# (194, 9)

# %%
# here we need to work on only column from x to remove the multicollinearity , where rows=0 and columns=1

x1.shape[1]
# Out:
# 9

# %% [markdown]
# # Use of VIF for Multicollinearity

# %%
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal(x1):
    vif = pd.DataFrame()
    vif['Variables'] = x1.columns
    vif['VIF factor'] = [variance_inflation_factor(x1.values ,i) for i in range(x1.shape[1])]
    return(vif)

vif_cal(x1)
# Out:
#   Variables     VIF factor
# 0        RI  812862.993240
# 1        Na   26402.560852
# 2        Mg      85.737811
# 3        Al     211.564749
# 4        Si  473275.184189
# 5         K      26.348171
# 6        Ca    6278.629601
# 7        Ba       4.448201
# 8        Fe       1.548621

# %% [markdown]
# as per above we can see that Na and Al is highly correlated ,so we will drop it.

# %%
x1 = glsdf.drop(['Na'],axis=1)

# %%
vif_cal(x1)
# Out:
#   Variables     VIF factor
# 0        RI  211334.854721
# 1        Mg      43.475519
# 2        Al     225.887079
# 3        Si  184722.690259
# 4         K      13.449564
# 5        Ca    2487.016307
# 6        Ba       3.971777
# 7        Fe       1.573133
# 8      Type      55.679017

# %%
x=x1

# %% [markdown]
# now we will do train_test_split method

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x,y, test_size=.30 , random_state=45)

# %%
x_train.shape
# Out:
# (135, 9)

# %%
x_test.shape
# Out:
# (59, 9)

# %%
y_train.shape
# Out:
# (135,)

# %%
y_test.shape
# Out:
# (59,)

# %% [markdown]
# # Applying models

# %%
import sklearn
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error , accuracy_score

# %%
lr = LinearRegression()
lr.fit(x_train ,y_train)
pred_lr = lr.predict(x_test)
print('Linear Regression')

print('r2 score',r2_score(y_test,pred_lr))
print('mean square error:',mean_squared_error(y_test,pred_lr))
print('mean absolute error:',mean_absolute_error(y_test,pred_lr))
print('squared root:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Linear Regression
# r2 score 1.0
# mean square error: 1.8029315709897594e-31
# mean absolute error: 3.3306690738754696e-16
# squared root: 4.2460941711056754e-16

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
print('Decision Tree Regressor')

print('r2 score:',r2_score(y_test,pred_dtr))
print('mean squared error:',mean_squared_error(y_test,pred_dtr))
print('mean absolute error :',mean_absolute_error(y_test,pred_dtr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# Decision Tree Regressor
# r2 score: 0.9951351545687277
# mean squared error: 0.0006223504504880467
# mean absolute error : 0.006495633216288214
# squared root error: 0.02494695272950279

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(x_train , y_train)
pred_svr = svr.predict(x_test)
print('Support vector Regressor')

print('r2 score:',r2_score(y_test,pred_svr))
print('mean squared error:',mean_squared_error(y_test,pred_svr))
print('mean absolute error:',mean_absolute_error(y_test,pred_svr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# Support vector Regressor
# r2 score: 0.9353281435592946
# mean squared error: 0.008273347952854676
# mean absolute error: 0.07288520986469617
# squared root error: 0.0909579460677003

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
pred_knr = knr.predict(x_test)
print('KNeighbors Regressor')

print('r2 score:',r2_score(y_test,pred_knr))
print('mean squared error:',mean_squared_error(y_test,pred_knr))
print('mean absolute error:',mean_absolute_error(y_test,pred_knr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_knr)))
# Out:
# KNeighbors Regressor
# r2 score: 0.8540765008632125
# mean squared error: 0.01866771651999238
# mean absolute error: 0.04572551247730612
# squared root error: 0.1366298522285389

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr = rfr.predict(x_test)
print('Random Forest Regressor')

print('r2 score:',r2_score(y_test,pred_rfr))
print('mean squared error:',mean_squared_error(y_test,pred_rfr))
print('mean absolute error:',mean_absolute_error(y_test,pred_rfr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# Random Forest Regressor
# r2 score: 0.9951513153700131
# mean squared error: 0.000620283029826412
# mean absolute error: 0.007894195962212849
# squared root error: 0.024905481923191367

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso(alpha=0.01)
ls.fit(x_train,y_train)
pred_ls = ls.predict(x_test)
print('Lasso Regressor')

print('r2 score:',r2_score(y_test,pred_ls))
print('mean squared error:',mean_squared_error(y_test,pred_ls))
print('mean absolute error:',mean_absolute_error(y_test,pred_ls))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Lasso Regressor
# r2 score: 0.9843183540296468
# mean squared error: 0.002006123230823982
# mean absolute error: 0.03528456628307865
# squared root error: 0.04478976703248167

# %%
from sklearn.linear_model import Ridge

# %%
rd = Ridge(alpha=0.001)
rd.fit(x_train , y_train)
pred_rd = rd.predict(x_test)
print('Ridge Regressor')

print('r2 score:',r2_score(y_test,pred_rd))
print('mean squared error:',mean_squared_error(y_test,pred_rd))
print('mean absolute error:',mean_absolute_error(y_test,pred_rd))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge Regressor
# r2 score: 0.9999999583737724
# mean squared error: 5.3251643536826395e-09
# mean absolute error: 5.106467928789609e-05
# squared root error: 7.297372372082049e-05

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr = gbr.predict(x_test)
print('Gradient Boosting Regressor')

print('r2 score:',r2_score(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('mean absolute error:',mean_absolute_error(y_test,pred_gbr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# Gradient Boosting Regressor
# r2 score: 0.997505117281878
# mean squared error: 0.0003191656149149194
# mean absolute error: 0.005334828161315542
# squared root error: 0.01786520682541681

# %%
from sklearn.ensemble import BaggingRegressor

# %%
br = BaggingRegressor()
br.fit(x_train,y_train)
pred_br = br.predict(x_test)
print('Bagging Regressor')

print('r2 score:',r2_score(y_test,pred_br))
print('mean squared error:',mean_squared_error(y_test,pred_br))
print('mean absolute error:',mean_absolute_error(y_test,pred_br))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_br)))
# Out:
# Bagging Regressor
# r2 score: 0.9825390931776661
# mean squared error: 0.002233740697485481
# mean absolute error: 0.01424132861060027
# squared root error: 0.04726246605378819

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(lr,x,y)
print('score1:',score1)
print('score1 mean:',score1.mean())
print('score1 std:',score1.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_lr)-score1.mean())*100)
# Out:
# score1: [0.         1.         0.73076923 1.         1.        ]
# score1 mean: 0.7461538461538462
# score1 std: 0.38737471729274375
# Difference between r2 score and mean: 25.384615384615383

# %%
score2 = cross_val_score(dtr,x,y)
print('score2:',score2)
print('score2 mean:',score2.mean())
print('score2 std:',score2.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_dtr)-score2.mean())*100)
# Out:
# score2: [ 1.          1.          0.76282051  0.0558277  -5.69934261]
# score2 mean: -0.5761388786901306
# score2 std: 2.584872839934156
# Difference between r2 score and mean: 157.1274033258858

# %%
score3 = cross_val_score(svr,x,y)
print('score3:',score3)
print('score3 mean:',score3.mean())
print('score3 std:',score3.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_svr)-score3.mean())*100)
# Out:
# score3: [ 0.00000000e+00  3.92469145e-01 -9.96764973e+27  9.13749153e-01
#  -1.64933816e+01]
# score3 mean: -1.9935299450195086e+27
# score3 std: 3.987059890039018e+27
# Difference between r2 score and mean: 1.9935299450195086e+29

# %%
score4 = cross_val_score(knr,x,y)
print('score4:',score4)
print('score4 mean:',score4.mean())
print('score4 std:',score4.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_knr)-score4.mean())*100)
# Out:
# score4: [ 0.00000000e+00  8.30821633e-01 -6.65565679e+28 -3.91878820e-01
#  -4.05626549e+01]
# score4 mean: -1.3311313585030684e+28
# score4 std: 2.6622627170061368e+28
# Difference between r2 score and mean: 1.3311313585030685e+30

# %%
score5 = cross_val_score(rfr,x,y)
print('score5:',score5)
print('score5 mean:',score5.mean())
print('score5 std:',score5.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_rfr)-score5.mean())*100)
# Out:
# score5: [  1.           1.         -11.25         0.05399924 -10.67334419]
# score5 mean: -3.973868990953089
# score5 std: 5.7188725888010525
# Difference between r2 score and mean: 496.90203063231024

# %%
score6 = cross_val_score(ls,x,y)
print('score6:',score6)
print('score6 mean:',score6.mean())
print('score6 std:',score6.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_ls)-score6.mean())*100)
# Out:
# score6: [ 0.00000000e+00  8.79072413e-01 -2.34498218e+26  9.70421135e-01
#  -8.96510994e+00]
# score6 mean: -4.6899643559215346e+25
# score6 std: 9.379928711843069e+25
# Difference between r2 score and mean: 4.6899643559215345e+27

# %%
score7 = cross_val_score(rd ,x,y)
print('score7:',score7)
print('score7 mean:',score7.mean())
print('score7 std:',score7.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_rd)-score7.mean())*100)
# Out:
# score7: [ 0.00000000e+00  9.99999843e-01 -1.85262332e+21  9.99999818e-01
#   9.99998154e-01]
# score7 mean: -3.705246633504414e+20
# score7 std: 7.410493267008828e+20
# Difference between r2 score and mean: 3.705246633504414e+22

# %%
score8 = cross_val_score(gbr,x,y)
print('score8:',score8)
print('score8 mean:',score8.mean())
print('score8 std:',score8.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_gbr)-score8.mean())*100)
# Out:
# score8: [ 0.00000000e+00  9.99999993e-01 -1.01348456e+19  5.58355684e-02
#  -7.85049308e+00]
# score8 mean: -2.0269691280138212e+18
# score8 std: 4.0539382560276424e+18
# Difference between r2 score and mean: 2.026969128013821e+20

# %%
score9 = cross_val_score(br,x,y)
print('score9:',score9)
print('score9 mean:',score9.mean())
print('score9 std:',score9.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_br)-score9.mean())*100)
# Out:
# score9: [  1.           1.           0.93589744   0.0558277  -10.0181282 ]
# score9 mean: -1.405280611963716
# score9 std: 4.321292522663971
# Difference between r2 score and mean: 238.7819705141382

# %% [markdown]
# As per above results KNeighbors Regressor is the best model as its has lowest differnce between r2 score and mean . Hence it will be used for further prediction.

# %% [markdown]
# # Finalizing Model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
final_model = KNeighborsRegressor()

# %%
final_model.fit(x_train ,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred = final_model.predict(x_test)

# %%
print(pred)
# Out:
# [1.         1.25992105 1.         1.         1.         1.
#  1.91293118 1.25992105 1.         1.         1.25992105 1.44224957
#  1.54934012 1.         1.         1.91293118 1.52995399 1.61996497
#  1.25992105 1.22888404 1.25992105 1.25992105 1.         1.25992105
#  1.         1.         1.31733395 1.54934012 1.         1.74214639
#  1.91293118 1.         1.25992105 1.91293118 1.25992105 1.91293118
#  1.         1.74214639 1.         1.         1.44224957 1.25992105
#  1.25992105 1.         1.20793684 1.25992105 1.91293118 1.
#  1.15595263 1.25992105 1.91293118 1.25992105 1.39052308 1.25992105
#  1.         1.25992105 1.91293118 1.91293118 1.25992105]

# %% [markdown]
# # Saving Best Model

# %%
import joblib

# %%
joblib.dump(final_model,'glass_identification.pkl')
# Out:
# ['glass_identification.pkl']

# %%
# predicting the saved model

model = joblib.load('glass_identification.pkl')

# prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([1.        , 1.25992105, 1.        , 1.        , 1.        ,
#        1.        , 1.91293118, 1.25992105, 1.        , 1.        ,
#        1.25992105, 1.44224957, 1.54934012, 1.        , 1.        ,
#        1.91293118, 1.52995399, 1.61996497, 1.25992105, 1.22888404,
#        1.25992105, 1.25992105, 1.        , 1.25992105, 1.        ,
#        1.        , 1.31733395, 1.54934012, 1.        , 1.74214639,
#        1.91293118, 1.        , 1.25992105, 1.91293118, 1.25992105,
#        1.91293118, 1.        , 1.74214639, 1.        , 1.        ,
#        1.44224957, 1.25992105, 1.25992105, 1.        , 1.20793684,
#        1.25992105, 1.91293118, 1.        , 1.15595263, 1.25992105,
#        1.91293118, 1.25992105, 1.39052308, 1.25992105, 1.        ,
#        1.25992105, 1.91293118, 1.91293118, 1.25992105])

# %% [markdown]
# # Checking the predicted model is correct result

# %%
a = np.array(y_test)
glsdf = pd.DataFrame()
glsdf['predicted'] = prediction
glsdf['original']=a
glsdf
# Out:
#     predicted  original
# 0    1.000000  1.000000
# 1    1.259921  1.259921
# 2    1.000000  1.000000
# 3    1.000000  1.000000
# 4    1.000000  1.000000
# 5    1.000000  1.000000
# 6    1.912931  1.912931
# 7    1.259921  1.259921
# 8    1.000000  1.000000
# 9    1.000000  1.000000
# 10   1.259921  1.259921
# 11   1.442250  1.442250
# 12   1.549340  1.709976
# 13   1.000000  1.000000
# 14   1.000000  1.000000
# 15   1.912931  1.912931
# 16   1.529954  1.817121
# 17   1.619965  1.817121
# 18   1.259921  1.259921
# 19   1.228884  1.259921
# 20   1.259921  1.259921
# 21   1.259921  1.259921
# 22   1.000000  1.000000
# 23   1.259921  1.259921
# 24   1.000000  1.000000
# 25   1.000000  1.000000
# 26   1.317334  1.442250
# 27   1.549340  1.912931
# 28   1.000000  1.000000
# 29   1.742146  1.817121
# 30   1.912931  1.912931
# 31   1.000000  1.000000
# 32   1.259921  1.259921
# 33   1.912931  1.912931
# 34   1.259921  1.259921
# 35   1.912931  1.912931
# 36   1.000000  1.000000
# ...

# %% [markdown]
# as per above result predicted and original result is equal.
