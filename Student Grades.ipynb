# %% [markdown]
# # Student_Grades_Prediction

# %%
# import libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# getting dataset

sgds = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')
sgds
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# in this dataset we have 571 rows and 43 columns .

# %% [markdown]
# # Now converting csv dataset into DataFrame

# %%
sgdf = pd.DataFrame(data= sgds)
sgdf
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# Now dataset is converted in to DataFrame.

# %% [markdown]
# # Performing EDA

# %%
sgdf.shape
# Out:
# (571, 43)

# %%
sgdf.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
sgdf.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [markdown]
# As per above we can see that there are 2 data type (object and float).

# %%
sgdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
sgdf.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %% [markdown]
# It gives the statistical information of numerical data.

# %% [markdown]
# Here we can see that there is little difference between mean and median.

# %% [markdown]
# We can also see that there is little difference between 75% and max . Hence there might be some outlier present in the dataset.

# %% [markdown]
# # Checking for null value

# %%
sgdf.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# as per above details there is null value present .

# %%
# checking null value using heatmap

sns.heatmap(sgdf.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap also shows that there is null value present in dataset.

# %% [markdown]
# For integer column mean and median is used to remove null values.

# %% [markdown]
# For String column we need to used mode to remove null values.

# %% [markdown]
# Here we will remove the null values from each columns one by one.

# %% [markdown]
# But first we will drop the column which is not needed much.

# %%
# dropping seat no column

sgdf.drop('Seat No.', axis=1 , inplace=True)

# %%
sgdf
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %% [markdown]
# here we see that Seat NO. column is successfully dropped.

# %% [markdown]
# # Removing nan or null values

# %% [markdown]
# Removing null values of all the columns together using for loop.

# %%
columns =['CY-105', 'HS-105/12', 'MT-111','CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214','EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412']

for i in columns:
    sgdf[i].fillna(sgdf[i].mode()[0],inplace=True)
    print(sgdf.isnull().sum())
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# ...

# %% [markdown]
# now we can see that all the null values is removed .

# %% [markdown]
# # Seperating Numerical and categorical column.

# %%
categorical =[]
for i in sgdf.dtypes.index:
    if sgdf.dtypes[i] == 'object':
        categorical.append(i)
    print('Categorical column:',categorical)
# Out:
# Categorical column: ['PH-121']
# Categorical column: ['PH-121', 'HS-101']
# Categorical column: ['PH-121', 'HS-101', 'CY-105']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107']
# Categorical column: ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107']
# ...

# %%
numerical =[]
for i in sgdf.dtypes.index:
    if sgdf.dtypes[i] != 'object':
        numerical.append(i)
    print('Numerical columns:',numerical)
# Out:
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# Numerical columns: []
# ...

# %%
# checking the number of unique values in each column

sgdf.nunique().to_frame('No of unique values')
# Out:
#            No of unique values
# PH-121                      13
# HS-101                      12
# CY-105                      13
# HS-105/12                   13
# MT-111                      13
# CS-105                      11
# CS-106                      13
# EL-102                      13
# EE-119                      12
# ME-107                      13
# CS-107                      14
# HS-205/20                   13
# MT-222                      14
# EE-222                      13
# MT-224                      14
# CS-210                      14
# CS-211                      14
# CS-203                      13
# CS-214                      13
# EE-217                      13
# CS-212                      12
# CS-215                      14
# MT-331                      12
# EF-303                      12
# HS-304                      14
# CS-301                      12
# CS-302                      11
# TC-383                      12
# MT-442                      12
# ...

# %% [markdown]
# Here we can see that almost every column has unqiue values.

# %% [markdown]
# # Converting Categorical data into numerical data

# %% [markdown]
# now we can converting categorical data into numerical data using label encoder.

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
columns=['PH-121','HS-101', 'CY-105', 'HS-105/12', 'MT-111','CS-105','CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412']

sgdf[columns] = sgdf[columns].apply(le.fit_transform)

# %%
sgdf
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %% [markdown]
# Now all the data is successfully converted in to numerical dataset.

# %% [markdown]
# # Lets Check Correlation

# %%
sgdf_corr = sgdf.corr()
sgdf_corr
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.557843   0.498561  0.468968  0.609990
# HS-101     0.382436  1.000000  0.335074   0.473132  0.432742  0.400713
# CY-105     0.557843  0.335074  1.000000   0.510123  0.538380  0.578573
# HS-105/12  0.498561  0.473132  0.510123   1.000000  0.494731  0.482406
# MT-111     0.468968  0.432742  0.538380   0.494731  1.000000  0.393684
# CS-105     0.609990  0.400713  0.578573   0.482406  0.393684  1.000000
# CS-106     0.293963  0.312019  0.378223   0.499093  0.500729  0.286324
# EL-102     0.423942  0.349412  0.447539   0.360304  0.555895  0.353949
# EE-119     0.579964  0.309697  0.467250   0.400303  0.409161  0.507357
# ME-107     0.533558  0.336545  0.464418   0.320137  0.471685  0.455470
# CS-107     0.477761  0.495906  0.481277   0.540405  0.488977  0.503239
# HS-205/20  0.296428  0.178344  0.261281   0.179766  0.328574  0.192982
# ...

# %%
# heatmap for correlation

plt.figure(figsize=(10,6))
sns.heatmap(sgdf_corr)
plt.show()

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1. Univariant Analysis

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['PH-121'])
print(sgdf['PH-121'].value_counts())
plt.show()
# Out:
# 2     112
# 0     111
# 4      61
# 3      57
# 5      56
# 9      44
# 6      33
# 7      31
# 10     22
# 1      22
# 8      19
# 12      2
# 11      1
# Name: PH-121, dtype: int64

# %% [markdown]
# as per this plot we can see that 0 and 1 is highest and 11 is lowest.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['HS-101'])
print(sgdf['HS-101'].value_counts())
plt.show()
# Out:
# 2     82
# 5     78
# 6     68
# 3     63
# 4     59
# 8     50
# 7     47
# 9     45
# 0     38
# 10    36
# 1      4
# 11     1
# Name: HS-101, dtype: int64

# %% [markdown]
# in this plot we can see that HS-101 is high at 2 and low at 11 point.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CY-105'])
print(sgdf['CY-105'].value_counts())
plt.show()
# Out:
# 0     178
# 2     120
# 4      50
# 3      49
# 5      42
# 9      31
# 1      31
# 6      19
# 7      17
# 8      16
# 10     14
# 12      3
# 11      1
# Name: CY-105, dtype: int64

# %% [markdown]
# in CY-105 0 is high and 11 is low .

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['HS-105/12'])
print(sgdf['HS-105/12'].value_counts())
plt.show()
# Out:
# 0     97
# 2     75
# 4     70
# 3     57
# 9     45
# 6     41
# 5     40
# 7     39
# 8     36
# 10    34
# 1     34
# 12     2
# 11     1
# Name: HS-105/12, dtype: int64

# %% [markdown]
# as per above plot in HS-105/12  11 is lowest and 0 is highest.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['MT-111'])
print(sgdf['MT-111'].value_counts())
plt.show()
# Out:
# 2     107
# 0     100
# 5      70
# 4      62
# 3      55
# 8      39
# 7      33
# 6      30
# 9      26
# 1      23
# 10     21
# 12      3
# 11      2
# Name: MT-111, dtype: int64

# %% [markdown]
# in this plot of MT-111 is high at 2 and low at 11.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-105'])
print(sgdf['CS-105'].value_counts())
plt.show()
# Out:
# 0     151
# 2     134
# 4      60
# 3      51
# 1      43
# 5      38
# 7      23
# 6      22
# 8      22
# 10     15
# 9      12
# Name: CS-105, dtype: int64

# %% [markdown]
# as per above plot CS-105 is high a 0 and low at 9.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-106'])
print(sgdf['CS-106'].value_counts())
plt.show()
# Out:
# 2     118
# 4     101
# 3      96
# 0      56
# 5      54
# 7      41
# 10     29
# 8      27
# 9      24
# 6      18
# 1       4
# 12      2
# 11      1
# Name: CS-106, dtype: int64

# %% [markdown]
# in CS-106 plot 11 is low and 2 has highest .

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EL-102'])
print(sgdf['EL-102'].value_counts())
plt.show()
# Out:
# 2     107
# 0      92
# 4      69
# 3      59
# 5      53
# 9      38
# 7      35
# 8      32
# 6      30
# 1      29
# 10     23
# 12      3
# 11      1
# Name: EL-102, dtype: int64

# %% [markdown]
# as per above plot we can see that 11 has lowest data and 2 has highest data.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EE-119'])
print(sgdf['EE-119'].value_counts())
plt.show()
# Out:
# 2     139
# 4      83
# 3      77
# 0      68
# 5      48
# 6      48
# 7      38
# 10     26
# 8      26
# 9      11
# 1       6
# 11      1
# Name: EE-119, dtype: int64

# %% [markdown]
# EE-119 plot has 11 has low data and 2 has high data.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['ME-107'])
print(sgdf['ME-107'].value_counts())
plt.show()
# Out:
# 2     81
# 0     77
# 4     68
# 9     56
# 5     56
# 3     50
# 6     49
# 8     48
# 7     37
# 10    37
# 1      8
# 12     2
# 11     2
# Name: ME-107, dtype: int64

# %% [markdown]
# in the plot ME-107 has 11 and 12 has lowest data.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-107'])
print(sgdf['CS-107'].value_counts())
plt.show()
# Out:
# 0     107
# 2      81
# 4      57
# 3      55
# 8      49
# 5      43
# 1      42
# 9      38
# 7      34
# 10     31
# 6      30
# 13      2
# 12      1
# 11      1
# Name: CS-107, dtype: int64

# %% [markdown]
# in the plot CS-107 is lowest at 11 and 12 .

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['HS-205/20'])
print(sgdf['HS-205/20'].value_counts())
plt.show()
# Out:
# 2     155
# 0     118
# 3      97
# 4      89
# 5      36
# 7      33
# 6      15
# 8      11
# 10      9
# 9       3
# 1       2
# 11      2
# 12      1
# Name: HS-205/20, dtype: int64

# %% [markdown]
# in this plot of HS-205/20 has low at 11 and 12 and high at 2.

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['MT-222'])
print(sgdf['MT-222'].value_counts())
plt.show()
# Out:
# 2     91
# 0     80
# 9     66
# 3     61
# 5     52
# 10    46
# 6     43
# 4     42
# 7     39
# 8     30
# 1     16
# 11     3
# 13     1
# 12     1
# Name: MT-222, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EE-222'])
print(sgdf['EE-222'].value_counts())
plt.show()
# Out:
# 0     129
# 2     121
# 4      65
# 3      53
# 6      39
# 5      35
# 1      32
# 7      29
# 9      25
# 10     21
# 8      16
# 11      4
# 12      2
# Name: EE-222, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['MT-224'])
print(sgdf['MT-224'].value_counts())
plt.show()
# Out:
# 2     127
# 0      80
# 4      65
# 3      57
# 5      49
# 8      43
# 7      39
# 10     37
# 9      31
# 6      30
# 1      10
# 13      1
# 12      1
# 11      1
# Name: MT-224, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-210'])
print(sgdf['CS-210'].value_counts())
plt.show()
# Out:
# 2     140
# 0     101
# 4      84
# 3      59
# 5      58
# 6      30
# 7      27
# 8      24
# 10     21
# 9      12
# 1      12
# 13      1
# 12      1
# 11      1
# Name: CS-210, dtype: int64

# %% [markdown]
# CS-210 as 11,12 and 13 is low data .

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-211'])
print(sgdf['CS-211'].value_counts())
plt.show()
# Out:
# 2     73
# 0     67
# 5     60
# 10    56
# 4     56
# 3     56
# 7     55
# 8     50
# 6     39
# 9     33
# 1     21
# 11     3
# 13     1
# 12     1
# Name: CS-211, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-203'])
print(sgdf['CS-203'].value_counts())
plt.show()
# Out:
# 2     93
# 0     81
# 3     66
# 7     62
# 4     59
# 5     53
# 10    39
# 6     35
# 8     35
# 9     30
# 1     15
# 11     2
# 12     1
# Name: CS-203, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-214'])
print(sgdf['CS-214'].value_counts())
plt.show()
# Out:
# 6     82
# 2     73
# 3     63
# 8     57
# 5     56
# 0     56
# 10    47
# 7     46
# 4     45
# 9     31
# 1     12
# 11     2
# 12     1
# Name: CS-214, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EE-217'])
print(sgdf['EE-217'].value_counts())
plt.show()
# Out:
# 2     143
# 0      97
# 4      70
# 3      63
# 5      57
# 6      36
# 7      29
# 1      22
# 8      20
# 10     19
# 9      12
# 11      2
# 12      1
# Name: EE-217, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-212'])
print(sgdf['CS-212'].value_counts())
plt.show()
# Out:
# 2     107
# 4      86
# 3      81
# 5      65
# 6      44
# 0      43
# 10     36
# 7      35
# 8      35
# 9      33
# 1       4
# 11      2
# Name: CS-212, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-215'])
print(sgdf['CS-215'].value_counts())
plt.show()
# Out:
# 2     85
# 0     68
# 3     64
# 5     59
# 7     50
# 4     50
# 6     48
# 8     47
# 9     42
# 10    38
# 1     17
# 13     1
# 12     1
# 11     1
# Name: CS-215, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['MT-331'])
print(sgdf['MT-331'].value_counts())
plt.show()
# Out:
# 0     127
# 2     103
# 4      64
# 3      57
# 5      46
# 8      32
# 10     31
# 1      30
# 6      28
# 7      27
# 9      22
# 11      4
# Name: MT-331, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EF-303'])
print(sgdf['EF-303'].value_counts())
plt.show()
# Out:
# 2     122
# 4      92
# 5      61
# 3      59
# 6      58
# 7      56
# 9      49
# 1      38
# 8      19
# 0      14
# 10      2
# 11      1
# Name: EF-303, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['HS-304'])
print(sgdf['HS-304'].value_counts())
plt.show()
# Out:
# 2     138
# 3      72
# 5      70
# 4      66
# 6      58
# 7      53
# 8      33
# 0      28
# 9      20
# 10     19
# 11      6
# 1       4
# 13      2
# 12      2
# Name: HS-304, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-301'])
print(sgdf['CS-301'].value_counts())
plt.show()
# Out:
# 2     118
# 4      74
# 3      71
# 0      66
# 5      60
# 6      41
# 7      37
# 8      36
# 9      29
# 10     29
# 1       9
# 11      1
# Name: CS-301, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-302'])
print(sgdf['CS-302'].value_counts())
plt.show()
# Out:
# 2     123
# 3     102
# 0      86
# 4      81
# 5      60
# 7      32
# 6      28
# 9      21
# 8      19
# 10     10
# 1       9
# Name: CS-302, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['TC-383'])
print(sgdf['TC-383'].value_counts())
plt.show()
# Out:
# 0     115
# 2      73
# 4      68
# 3      59
# 7      44
# 10     44
# 8      42
# 6      42
# 5      40
# 1      23
# 9      20
# 11      1
# Name: TC-383, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['MT-442'])
print(sgdf['MT-442'].value_counts())
plt.show()
# Out:
# 2     150
# 0     130
# 4      65
# 3      47
# 1      39
# 5      30
# 8      28
# 7      24
# 6      24
# 9      20
# 10     13
# 11      1
# Name: MT-442, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['EL-332'])
print(sgdf['EL-332'].value_counts())
plt.show()
# Out:
# 2     105
# 0      76
# 4      68
# 3      67
# 5      62
# 6      49
# 7      38
# 8      32
# 10     22
# 9      22
# 1      20
# 11      9
# 12      1
# Name: EL-332, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-318'])
print(sgdf['CS-318'].value_counts())
plt.show()
# Out:
# 2     98
# 5     69
# 3     68
# 4     65
# 6     53
# 7     49
# 0     42
# 8     40
# 9     36
# 10    29
# 11    10
# 1      6
# 13     5
# 12     1
# Name: CS-318, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-306'])
print(sgdf['CS-306'].value_counts())
plt.show()
# Out:
# 2     129
# 4      75
# 0      74
# 5      64
# 3      53
# 8      40
# 6      37
# 7      36
# 9      31
# 10     18
# 1      10
# 11      3
# 12      1
# Name: CS-306, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-312'])
print(sgdf['CS-312'].value_counts())
plt.show()
# Out:
# 1     103
# 0      86
# 2      63
# 10     52
# 6      48
# 8      44
# 4      42
# 3      37
# 7      37
# 5      36
# 9      19
# 11      2
# 12      1
# 13      1
# Name: CS-312, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-317'])
print(sgdf['CS-317'].value_counts())
plt.show()
# Out:
# 5     91
# 3     75
# 6     70
# 2     66
# 4     58
# 7     57
# 0     47
# 8     41
# 10    34
# 9     16
# 1      9
# 11     7
# Name: CS-317, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-403'])
print(sgdf['CS-403'].value_counts())
plt.show()
# Out:
# 0     145
# 2     106
# 4      62
# 5      55
# 3      54
# 10     35
# 6      33
# 7      32
# 8      30
# 1      15
# 9       4
# Name: CS-403, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-421'])
print(sgdf['CS-421'].value_counts())
plt.show()
# Out:
# 3     98
# 5     74
# 6     68
# 7     61
# 8     60
# 4     60
# 2     47
# 10    36
# 0     25
# 9     21
# 11    17
# 1      2
# 12     2
# Name: CS-421, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-406'])
print(sgdf['CS-406'].value_counts())
plt.show()
# Out:
# 2     262
# 0      79
# 4      64
# 3      58
# 5      22
# 7      22
# 6      19
# 10     14
# 8       8
# 1       8
# 11      6
# 9       5
# 12      3
# 13      1
# Name: CS-406, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-414'])
print(sgdf['CS-414'].value_counts())
plt.show()
# Out:
# 0     189
# 2     156
# 4      62
# 3      54
# 5      21
# 1      21
# 7      21
# 6      20
# 8      12
# 11      7
# 10      3
# 9       3
# 12      2
# Name: CS-414, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-419'].value_counts())
print(sgdf['CS-419'].value_counts())
plt.show()
# Out:
# 2     133
# 3      89
# 4      85
# 5      78
# 0      56
# 7      46
# 6      40
# 8      20
# 10     13
# 9       7
# 1       2
# 11      2
# Name: CS-419, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-423'])
print(sgdf['CS-423'].value_counts())
plt.show()
# Out:
# 2     136
# 0      78
# 4      75
# 3      65
# 5      56
# 6      45
# 7      39
# 8      29
# 10     25
# 9      15
# 11      5
# 1       3
# Name: CS-423, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(sgdf['CS-412'])
print(sgdf['CS-412'].value_counts())
plt.show()
# Out:
# 2     236
# 4      80
# 0      77
# 3      65
# 5      37
# 7      24
# 6      19
# 10      8
# 8       7
# 11      6
# 9       5
# 1       4
# 12      3
# Name: CS-412, dtype: int64

# %% [markdown]
# 2 Univariate Analysis

# %%
# comparison between PH-121 and HS-101

plt.figure(figsize=(8,4))
plt.title('Comparision between PH-121 and HS-101')
sns.stripplot(x='PH-121',y='HS-101',data=sgdf,palette='deep')
plt.show()

# %% [markdown]
# as per above comparision we can see that PH-121 and HS-101 is equally distributed .

# %%
# comparision between HS-101 and CY-105

plt.figure(figsize=(8,4))
plt.title('Comparision between HS-101 amd CY-105')
sns.scatterplot(x='HS-101',y='CY-105',data=sgdf,palette='cividis')
plt.show()

# %% [markdown]
# in the above plot we can see that CY-105 and HS-101 has distributed equally but between 0 and 2 has lowest data.

# %%
# comparision between HS-105/12 and MT-111

plt.figure(figsize=(8,4))
plt.title('comparision between HS-105/12 and MT-111')
sns.stripplot(x='HS-105/12',y='MT-111',data=sgdf,palette='deep')
plt.show()

# %% [markdown]
# in this comparision we can see that MT-111 and HS-105/12 has low value in 11 and 12.

# %%
# comparision between CS-105 and CS-106

plt.figure(figsize=(8,4))
plt.title('comparision between CS-105 and CS-106')
sns.stripplot(x='CS-105',y='CS-106',data=sgdf,palette='bright')
plt.show()

# %% [markdown]
# in the above plot both CS-106 and CS-105 is equally distributed.

# %%
# comparision between EL-102 and EE-119

plt.figure(figsize=(8,4))
plt.title('Comparision between EL-102 and EE-119')
sns.scatterplot(x='EL-102',y='EE-119',data=sgdf,palette='icefire')
plt.show()

# %%
# comparision between ME-107 and CS-107

plt.figure(figsize=(8,4))
plt.title('comparision between ME-107  and CS-107')
sns.stripplot(x='ME-107',y='CS-107',data=sgdf,palette='cividis')
plt.show()

# %%
# comparision between HS-205/20 and MT-222

plt.figure(figsize=(8,4))
plt.title('comparision between HS-205/20 and MT-222')
sns.stripplot(x='HS-205/20',y='MT-222',data=sgdf,palette='cividis')
plt.show()

# %%
# comparision between HS-205/20 and MT-222

plt.figure(figsize=(8,4))
plt.title('comparision between HS-205/20 and MT-222')
sns.scatterplot(x='HS-205/20',y='MT-222',data=sgdf,palette='deep')
plt.show()

# %%
# comparision between EE-222 and MT-224

plt.figure(figsize=(8,4))
plt.title('comparision between EE-222 and MT-224')
sns.stripplot(x='EE-222',y='MT-224',data=sgdf , palette='deep')
plt.show()

# %%
# comparision between CS-210 , CS-211

plt.figure(figsize=(8,4))
plt.title('comparision between CS-210 and CS-211')
sns.lmplot(x='CS-210',y='CS-211',data=sgdf,palette='bright')
plt.show()

# %%
# comparision between CS-214 and CS-203

plt.figure(figsize=(8,4))
plt.title('comparision between CS-214 and CS-203')
sns.stripplot(x='CS-214',y='CS-203',data=sgdf,palette='cividis')
plt.show()

# %%
# comparision between EE-217 and CS-212

plt.figure(figsize=(8,4))
plt.title('comparision between EE-217 and CS-212')
sns.stripplot(x='EE-217',y='CS-212',data=sgdf,palette='spring_r')
plt.show()

# %%
# comparision between CS-215 and MT-331

plt.figure(figsize=(8,4))
plt.title('Comparision between CS-215 and MT-331')
sns.scatterplot(x='CS-215',y='MT-331',data=sgdf,palette='deep')
plt.show()

# %%
# comparision between EF-303 and HS-304

plt.figure(figsize=(8,4))
plt.title('comparision between EF-303 and HS-304')
sns.stripplot(x='HS-304',y='EF-303',data=sgdf,palette='bright')
plt.show()

# %%
# comparision between CS=301 and CS-302

plt.title('comparision betweeb CS-301 and CS-302')
plt.figure(figsize=(8,4))
sns.regplot(x='CS-301',y='CS-302',data=sgdf)
plt.show()

# %%
# comparision between TC-383 and MT-442

plt.title('compariosion between TC-383 and MT-442')
plt.figure(figsize=(8,4))
sns.stripplot(x='TC-383',y='MT-442',data=sgdf ,palette='cividis')
plt.show()

# %%
# checking CGPA with CS-412
sns.catplot(x='CGPA',y='CS-412',data=sgdf,palette='deep')

# Checking CGPA with CS-414
sns.catplot(x='CGPA',y='CS-414',data=sgdf,palette='spring_r')

# checking CGPA with CS-421
sns.catplot(x='CGPA',y='CS-421',data=sgdf,palette='spring_r')

# checking CGPS with CS-406
sns.catplot(x='CGPA',y='CS-406',data=sgdf,palette='deep')

# Checking CGPA with CS-403
sns.catplot(x='CGPA',y='CS-403',data=sgdf,palette='cividis')

# Checking CGPA with CS-423
sns.catplot(x='CGPA',y='CS-423',data=sgdf ,palette='bright')

# %% [markdown]
# In first plot we can see that CS-412 and CGPA point 2 has maximum of data.

# %% [markdown]
# In 2nd plot we see that CS-414 and CGPA point 2 and 0 has maximum data.

# %% [markdown]
# In 3rd plot CGPA and CS-421 has maximum data at 6 and 8.

# %% [markdown]
# In 4th plot CGPA and CS-406 has maximum value at 2 point.

# %% [markdown]
# In 5th plot CGPA and CS-403 point 0,2,4,6 has maximum values.

# %% [markdown]
# In 6th plot CGPA and CS-423 all values is distribute almost at all the points.

# %%
sns.catplot(x='MT-111',hue='CGPA',data=sgdf,palette='cividis',kind='count')

# %% [markdown]
# Here we can see tha point 10 has maximum value.

# %% [markdown]
# 3. Multivariate Analysis

# %%
sgdf.hist(bins=20, figsize=(10,10))
plt.show()

# %%
sgdf.plot(kind='kde' , subplots=True , figsize=(15,6))
# Out:
# array([<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# # Checking Skewness

# %%
sgdf.skew()
# Out:
# PH-121       0.549104
# HS-101       0.053303
# CY-105       0.982144
# HS-105/12    0.324183
# MT-111       0.484906
# CS-105       0.930769
# CS-106       0.639845
# EL-102       0.501161
# EE-119       0.574880
# ME-107       0.108385
# CS-107       0.414846
# HS-205/20    0.897186
# MT-222       0.193993
# EE-222       0.759105
# MT-224       0.430480
# CS-210       0.723967
# CS-211       0.116085
# CS-203       0.274205
# CS-214       0.013129
# EE-217       0.724325
# CS-212       0.414872
# CS-215       0.163631
# MT-331       0.627721
# EF-303       0.383655
# HS-304       0.544843
# CS-301       0.415084
# CS-302       0.601788
# TC-383       0.331652
# MT-442       0.869952
# EL-332       0.459160
# CS-318       0.356504
# CS-306       0.424753
# CS-312       0.442525
# CS-317       0.140692
# CS-403       0.618339
# CS-421       0.179508
# CS-406       1.522703
# CS-414       1.292931
# CS-419       0.506748
# CS-423       0.526550
# CS-412       1.329362
# ...

# %% [markdown]
# there is not much skewness present in this dataset.

# %% [markdown]
# # Checking Outlier

# %%
plt.figure(figsize=(20,10))
sgdf.boxplot()
plt.show()

# %% [markdown]
# as per above plot we can see that there is some outlier present in some of the columns and we need to remove it.

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(sgdf))
z
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.400402  1.770900  1.722261   0.549869  1.374222  2.657832  1.790004
# 1    1.242052  1.411559  2.397448   1.488043  0.369509  1.173242  1.790004
# 2    1.242052  0.744483  0.978490   0.237145  0.034605  1.053643  0.322008
# 3    1.714365  0.692879  2.397448   1.488043  1.709126  0.311348  2.157003
# 4    0.585070  1.103823  0.303302   0.075580  1.305012  1.053643  0.778989
# ..        ...       ...       ...        ...       ...       ...       ...
# 566  0.256579  1.822504  0.978490   0.701029  0.970108  1.053643  0.778989
# 567  0.913561  1.822504  0.978490   1.326478  1.305012  1.053643  1.512987
# 568  0.256579  1.822504  0.303302   0.075580  1.305012  1.053643  1.512987
# 569  1.242052  0.385142  2.059854   1.326478  1.709126  2.657832  0.322008
# 570  0.728893  1.411559  2.059854   0.549869  0.704413  2.657832  0.411990
#
# ...

# %%
threasold = 3 
print(np.where(z>3))
# Out:
# (array([ 60,  60,  60,  91, 137, 143, 143, 281, 281, 281, 288, 288, 340,
#        340, 352, 352, 382, 387, 387, 410, 423, 424, 432, 446, 447, 447,
#        453, 453, 454, 454, 454, 509, 513, 516, 516, 521, 522, 522, 527,
#        543, 543, 550, 550, 557, 560, 563, 565, 570], dtype=int64), array([ 2, 11, 19, 15,  2,  2, 41, 11, 15, 41, 11, 41, 24, 37, 24, 37, 37,
#        37, 40, 37, 37, 37, 40, 36, 36, 37, 36, 40, 36, 37, 38, 36, 40, 36,
#        40, 36, 36, 40, 40, 36, 40, 37, 40, 37, 37, 38, 41, 36],
#       dtype=int64))

# %%
sgdf_new = sgdf[(z<3).all(axis=1)]
sgdf_new
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 564       2       9       0          6       4       4       6       2
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
sgdf_new.shape
# Out:
# (540, 42)

# %%
sgdf.shape
# Out:
# (571, 42)

# %%
sgdf=sgdf_new

# %% [markdown]
# here we have removed the outliers.

# %% [markdown]
# # Checking Multicollinearity

# %%
sgdf.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.349464  0.528068   0.481932  0.431073  0.587163
# HS-101     0.349464  1.000000  0.310953   0.478545  0.416890  0.373196
# CY-105     0.528068  0.310953  1.000000   0.493364  0.522462  0.566109
# HS-105/12  0.481932  0.478545  0.493364   1.000000  0.482151  0.466315
# MT-111     0.431073  0.416890  0.522462   0.482151  1.000000  0.358790
# CS-105     0.587163  0.373196  0.566109   0.466315  0.358790  1.000000
# CS-106     0.279904  0.325841  0.365001   0.484398  0.511237  0.291774
# EL-102     0.393218  0.329853  0.411126   0.334449  0.527899  0.318678
# EE-119     0.580401  0.305428  0.479126   0.371944  0.396185  0.497810
# ME-107     0.519364  0.326936  0.461730   0.289715  0.451997  0.430639
# CS-107     0.453251  0.494521  0.452693   0.524366  0.446487  0.495090
# HS-205/20  0.267973  0.148450  0.228452   0.151779  0.307402  0.141024
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(sgdf_corr , annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# as per above plot we can see that multicollinearity is present in the dataset and we need to remove it .

# %%
# assigning x and y value 

x1 = sgdf.iloc[:,:-1]
y = sgdf.iloc[:,-1]

# %%
x1.shape
# Out:
# (540, 41)

# %%
# now we will need only column from x1 where rows=0 and columns=1

x1.shape[1]
# Out:
# 41

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 564    2.607
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# Name: CGPA, Length: 540, dtype: float64

# %% [markdown]
# # Use of VIF

# %%
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def cal_vif(x1):
    vif = pd.DataFrame()
    vif['Variables'] = x1.columns
    vif['VIF factor'] = [variance_inflation_factor(x1.values , i) for i in range(x1.shape[1])]
    return(vif)

cal_vif(x1)
# Out:
#     Variables  VIF factor
# 0      PH-121    6.856604
# 1      HS-101    7.497345
# 2      CY-105    4.835603
# 3   HS-105/12    6.341560
# 4      MT-111    7.026033
# 5      CS-105    4.889494
# 6      CS-106    6.265304
# 7      EL-102    5.062777
# 8      EE-119    6.726685
# 9      ME-107    7.478361
# 10     CS-107    5.960795
# 11  HS-205/20    4.290256
# 12     MT-222    7.055480
# 13     EE-222    5.528311
# 14     MT-224    8.454735
# 15     CS-210    8.267659
# 16     CS-211    8.838762
# 17     CS-203    7.903895
# 18     CS-214   10.320288
# 19     EE-217    6.223110
# 20     CS-212   10.698152
# 21     CS-215    9.913903
# 22     MT-331    4.782282
# 23     EF-303    8.420086
# 24     HS-304    9.135585
# 25     CS-301    9.987780
# 26     CS-302    8.455302
# 27     TC-383    7.950669
# 28     MT-442    5.096117
# 29     EL-332    9.246186
# 30     CS-318    8.554347
# 31     CS-306   10.097036
# 32     CS-312    9.247925
# 33     CS-317   12.605059
# ...

# %% [markdown]
# # Use of PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 10)

# %%
x1 = pca.fit_transform(x1)

# %%
x1.shape
# Out:
# (540, 10)

# %% [markdown]
# here we cansee that after performing PCA number of columns is reduced to 10 for x1 .

# %%
x=x1

# %% [markdown]
# # Performing train_test_split method

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train ,y_test = train_test_split(x,y, test_size=.30 ,random_state=45)

# %%
x_train.shape
# Out:
# (378, 10)

# %%
x_test.shape
# Out:
# (162, 10)

# %%
y_train.shape
# Out:
# (378,)

# %%
y_test.shape
# Out:
# (162,)

# %% [markdown]
# # Applying Model & Cross Validation

# %% [markdown]
# now we will perform all the model together in one loop.

# %%
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor , BaggingRegressor

# %%
from sklearn.metrics import r2_score, mean_squared_error , mean_absolute_error , accuracy_score
from sklearn.model_selection import cross_val_score

# %%
models =[LinearRegression(),Lasso(alpha=0.001),Ridge(alpha=0.001),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),BaggingRegressor()]

for m in models:
    m.fit(x_train , y_train)
    pred_m = m.predict(x_test)
    print(m)
    print('r2 score:',r2_score(y_test,pred_m))
    print('mean squared error:',mean_squared_error(y_test,pred_m))
    print('mean absolute error:',mean_absolute_error(y_test,pred_m))
    print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_m)))
    print('\n')
# Out:
# LinearRegression()
# r2 score: 0.9237517919438537
# mean squared error: 0.026093023535232882
# mean absolute error: 0.05861421223404893
# squared root error: 0.16153335115459247
#
#
# Lasso(alpha=0.001)
# r2 score: 0.9238266827066958
# mean squared error: 0.026067395045236478
# mean absolute error: 0.05875140857729198
# squared root error: 0.16145400287771275
#
#
# Ridge(alpha=0.001)
# r2 score: 0.9237517928153731
# mean squared error: 0.026093023236988793
# mean absolute error: 0.058614212948667525
# squared root error: 0.16153335023142681
#
#
# DecisionTreeRegressor()
# r2 score: 0.9070448861656685
# mean squared error: 0.03181032098765432
# mean absolute error: 0.08237037037037037
# squared root error: 0.17835448126597303
#
#
# KNeighborsRegressor()
# r2 score: 0.900850832973113
# mean squared error: 0.033929998024691356
# mean absolute error: 0.0813111111111111
# squared root error: 0.18420097183427495
#
#
# RandomForestRegressor()
# r2 score: 0.9186287120900061
# ...

# %% [markdown]
# # Cross Validation

# %%
models =[LinearRegression(),Lasso(alpha=0.001),Ridge(alpha=0.001),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),BaggingRegressor()]

for i in models:
    score = cross_val_score(i,x,y,cv=6)
    print(i)
    print('score:',score)
    print('score mean:',score.mean())
    print('score std:',score.std())
    print('Differnce between r2 score and mean:',(r2_score(y_test,pred_m)-score.mean())*100)
    print('\n')
# Out:
# LinearRegression()
# score: [0.85097004 0.9876825  0.99086314 0.97193257 0.98159862 0.9788781 ]
# score mean: 0.960320825618762
# score std: 0.04927987785648686
# Differnce between r2 score and mean: -4.478658451562834
#
#
# Lasso(alpha=0.001)
# score: [0.85113817 0.98772901 0.99094921 0.97213819 0.98178723 0.97873989]
# score mean: 0.960413615476032
# score std: 0.049243994322489736
# Differnce between r2 score and mean: -4.487937437289835
#
#
# Ridge(alpha=0.001)
# score: [0.85097004 0.9876825  0.99086314 0.97193257 0.98159862 0.9788781 ]
# score mean: 0.9603208269846891
# score std: 0.04927987736258736
# Differnce between r2 score and mean: -4.4786585881555485
#
#
# DecisionTreeRegressor()
# score: [0.79150967 0.96556445 0.68246275 0.97692417 0.96425523 0.94195344]
# score mean: 0.887111618606236
# score std: 0.11120611023153
# Differnce between r2 score and mean: 2.8422622496897643
#
#
# KNeighborsRegressor()
# ...

# %% [markdown]
# as per above result we can see that Linear Regression has lowest difference between r2 score and mean . so its best fitting model and used for prediction.

# %%
final_model = LinearRegression()
final_model.fit(x_train , y_train)
pred = final_model.predict(x_test)
print(pred)
# Out:
# [2.41574329 2.22096295 2.6462657  3.78347392 2.72740192 2.58564843
#  2.9810616  2.34534534 2.41343601 2.74246356 2.8231728  3.3169152
#  2.27465477 3.78570245 3.90545395 2.92639322 2.66779515 2.71984437
#  2.66938992 2.33634258 3.37675713 2.86899279 3.5729944  3.7332444
#  2.88203895 3.19046434 3.9241568  3.21999121 2.2374268  3.81779074
#  2.93273024 2.14200315 3.11741168 3.70865718 2.58406723 3.19937823
#  3.14998838 2.35726155 3.28674855 2.66682495 3.82010428 2.86266415
#  3.00417621 3.90148764 2.58630403 3.21934758 2.41393466 3.84960092
#  3.15729783 3.37834879 3.671143   3.36015701 3.63064027 3.02416034
#  3.82947137 3.12431202 2.26453813 3.30586581 3.36346587 3.47934063
#  3.29196241 3.69257807 2.58653647 2.84528701 2.90357445 2.40042779
#  2.38615369 3.9968203  3.393113   2.20451109 2.50976057 3.10496204
#  3.67718077 1.99313309 2.02282328 1.77214126 3.03378645 3.5624285
#  2.78276051 3.26739055 3.68689105 3.91900466 3.10315131 3.28799738
# ...

# %% [markdown]
# # Saving Best Model

# %%
# saving best model using pkl

import joblib
joblib.dump(final_model,'student_grade.pkl')
# Out:
# ['student_grade.pkl']

# %%
# predicting the saved model
model = joblib.load('student_grade.pkl')

# prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([2.41574329, 2.22096295, 2.6462657 , 3.78347392, 2.72740192,
#        2.58564843, 2.9810616 , 2.34534534, 2.41343601, 2.74246356,
#        2.8231728 , 3.3169152 , 2.27465477, 3.78570245, 3.90545395,
#        2.92639322, 2.66779515, 2.71984437, 2.66938992, 2.33634258,
#        3.37675713, 2.86899279, 3.5729944 , 3.7332444 , 2.88203895,
#        3.19046434, 3.9241568 , 3.21999121, 2.2374268 , 3.81779074,
#        2.93273024, 2.14200315, 3.11741168, 3.70865718, 2.58406723,
#        3.19937823, 3.14998838, 2.35726155, 3.28674855, 2.66682495,
#        3.82010428, 2.86266415, 3.00417621, 3.90148764, 2.58630403,
#        3.21934758, 2.41393466, 3.84960092, 3.15729783, 3.37834879,
#        3.671143  , 3.36015701, 3.63064027, 3.02416034, 3.82947137,
#        3.12431202, 2.26453813, 3.30586581, 3.36346587, 3.47934063,
#        3.29196241, 3.69257807, 2.58653647, 2.84528701, 2.90357445,
#        2.40042779, 2.38615369, 3.9968203 , 3.393113  , 2.20451109,
# ...

# %% [markdown]
# # Checking the Predicted model is correct result

# %%
a = np.array(y_test)
sgdf = pd.DataFrame()
sgdf['predicted'] = prediction
sgdf['original'] = a

sgdf
# Out:
#      predicted  original
# 0     2.415743     2.468
# 1     2.220963     2.196
# 2     2.646266     2.698
# 3     3.783474     3.772
# 4     2.727402     2.636
# ..         ...       ...
# 157   2.780233     2.793
# 158   3.216863     3.269
# 159   3.604079     3.576
# 160   3.639299     3.607
# 161   3.466580     3.523
#
# [162 rows x 2 columns]

# %% [markdown]
# As per above data predicted and original data are same .
