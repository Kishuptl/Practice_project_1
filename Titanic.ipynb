# %% [markdown]
# # Titanic Survived Project

# %%
# import libraries

import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://github.com/dsrscientist/dataset1/blob/master/titanic_train.csv')
df

# %% [markdown]
# sometime raw dataset link is not working hence using csv file which is saved.

# %%
df = pd.read_csv('Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Now Converting csv data into DataFrame

# %%
titds = pd.DataFrame(data=df)
titds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# now dataset is converted in to DataFrame.

# %% [markdown]
# # Performing EDA

# %%
titds.shape
# Out:
# (891, 12)

# %%
    titds.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titds.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# here we can see the above dataset contain 891 rows and 12 columns out of which 11 columns is dependent variable and 1 column is independent variable.

# %%
titds.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titds.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# here we can see that mean and median is same for passange id but it is almost nearby for rest all.

# %%
# checking null values

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# as per above update we can see that there is null value present in age , cabin and embarked columns

# %%
# using heatmap for null values

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# above heatmap also shows that there is null value present in age , cabin columns.

# %% [markdown]
# for integer or numerical dataset we need to use mean or median to remove null values .

# %% [markdown]
# for string dataset we need to use mode to remove null values.

# %% [markdown]
# so now nan or null values is in age and embarked column so we will remove this values one by one for columns.

# %% [markdown]
# we will drop cabin column as it is not much needed.

# %%
# Dropping cabin column

titds.drop('Cabin', axis=1 , inplace=True)

# %%
titds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Here we can see that cabin column is drop successfully.

# %% [markdown]
# # Removing NaN values

# %% [markdown]
# for Age column::

# %%
titds['Age'].mean()
# Out:
# 29.69911764705882

# %%
# now replacing nan value using fillna 

titds['Age'] = titds['Age'].fillna(titds['Age'].mean())

# %%
# now rechecking nan value is removed or not

titds['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# now there is no nan values in age column.

# %%
# removing nan values for Embarked column 

print(titds['Embarked'].mode())   # as it has string data for the column so mode is used .
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
# replacing nan values with mode using fillna

titds['Embarked'] = titds['Embarked'].fillna(titds['Embarked'].mode()[0])  
# mode()[0] is used to select S for replacing nan values

# %%
# now rechecking nan values is removed or not

titds['Embarked'].isnull().sum()
# Out:
# 0

# %%
# checking nan value again

titds.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# now we can see that there is no nan values present in dataset.

# %% [markdown]
# # Seperating Categorical and numerical columns

# %% [markdown]
# categorical columns

# %%
categorical =[]
for i in titds.dtypes.index:
    if titds.dtypes[i] == 'object':
        categorical.append(i)
    print('Categorical column:',categorical)
# Out:
# Categorical column: []
# Categorical column: []
# Categorical column: []
# Categorical column: ['Name']
# Categorical column: ['Name', 'Sex']
# Categorical column: ['Name', 'Sex']
# Categorical column: ['Name', 'Sex']
# Categorical column: ['Name', 'Sex']
# Categorical column: ['Name', 'Sex', 'Ticket']
# Categorical column: ['Name', 'Sex', 'Ticket']
# Categorical column: ['Name', 'Sex', 'Ticket', 'Embarked']

# %% [markdown]
# Numerical Column

# %%
numerical =[]
for i in titds.dtypes.index:
    if titds.dtypes[i] != 'object':
        numerical.append(i)
    print('Numerical column:',numerical)
# Out:
# Numerical column: ['PassengerId']
# Numerical column: ['PassengerId', 'Survived']
# Numerical column: ['PassengerId', 'Survived', 'Pclass']
# Numerical column: ['PassengerId', 'Survived', 'Pclass']
# Numerical column: ['PassengerId', 'Survived', 'Pclass']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
# Numerical column: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# checking the number of unique values  in each column

titds.nunique().to_frame('No of unique values')
# Out:
#              No of unique values
# PassengerId                  891
# Survived                       2
# Pclass                         3
# Name                         891
# Sex                            2
# Age                           89
# SibSp                          7
# Parch                          7
# Ticket                       681
# Fare                         248
# Embarked                       3

# %% [markdown]
# There are the unique id present in the dataset.

# %% [markdown]
# # Converting categorical data into numerical data

# %% [markdown]
# now we will convert the string data in to integer data using label encoder.

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

# %%
le = LabelEncoder()

# %%
titds['Name'] = le.fit_transform(titds['Name'])
titds
# Out:
#      PassengerId  Survived  Pclass  Name     Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    male  22.000000      1      0
# 1              2         1       1   190  female  38.000000      1      0
# 2              3         1       3   353  female  26.000000      0      0
# 3              4         1       1   272  female  35.000000      1      0
# 4              5         0       3    15    male  35.000000      0      0
# ..           ...       ...     ...   ...     ...        ...    ...    ...
# 886          887         0       2   548    male  27.000000      0      0
# 887          888         1       1   303  female  19.000000      0      0
# 888          889         0       3   413  female  29.699118      1      2
# 889          890         1       1    81    male  26.000000      0      0
# 890          891         0       3   220    male  32.000000      0      0
#
#                Ticket     Fare Embarked
# ...

# %% [markdown]
# similarly we can convert other column which have categorical data.

# %%
titds['Sex'] = le.fit_transform(titds['Sex'])

# %%
titds['Ticket'] = le.fit_transform(titds['Ticket'])

# %%
titds['Embarked'] = le.fit_transform(titds['Embarked'])

# %%
titds
# Out:
#      PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    1  22.000000      1      0
# 1              2         1       1   190    0  38.000000      1      0
# 2              3         1       3   353    0  26.000000      0      0
# 3              4         1       1   272    0  35.000000      1      0
# 4              5         0       3    15    1  35.000000      0      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886          887         0       2   548    1  27.000000      0      0
# 887          888         1       1   303    0  19.000000      0      0
# 888          889         0       3   413    0  29.699118      1      2
# 889          890         1       1    81    1  26.000000      0      0
# 890          891         0       3   220    1  32.000000      0      0
#
#      Ticket     Fare  Embarked
# 0       523   7.2500         2
# 1       596  71.2833         0
# ...

# %% [markdown]
# now as per above dataset we can see that the complete dataset is now in numerical form.

# %% [markdown]
# # Lets check Correlation

# %%
titds_corr = titds.corr()
titds_corr
# Out:
#              PassengerId  Survived    Pclass      Name       Sex       Age  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.038559  0.042939  0.033207
# Survived       -0.005007  1.000000 -0.338481 -0.057343 -0.543351 -0.069809
# Pclass         -0.035144 -0.338481  1.000000  0.052831  0.131900 -0.331339
# Name           -0.038559 -0.057343  0.052831  1.000000  0.020314  0.057466
# Sex             0.042939 -0.543351  0.131900  0.020314  1.000000  0.084153
# Age             0.033207 -0.069809 -0.331339  0.057466  0.084153  1.000000
# SibSp          -0.057527 -0.035322  0.083081 -0.017230 -0.114631 -0.232625
# Parch          -0.001652  0.081629  0.018443 -0.049105 -0.245489 -0.179191
# Ticket         -0.056554 -0.164549  0.319869  0.047348  0.059372 -0.068848
# Fare            0.012658  0.257307 -0.549500 -0.049173 -0.182333  0.091566
# Embarked        0.013128 -0.167675  0.162098 -0.006117  0.108262 -0.026749
#
#                 SibSp     Parch    Ticket      Fare  Embarked
# ...

# %%
# heatmap for correlation

sns.heatmap(titds_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1. Univariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['PassengerId'])
print(df['PassengerId'].value_counts())
plt.show()
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Survived'])
print(df['Survived'].value_counts())
plt.show()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# as per the above plot we can see that maximum number of passengers is survived .

# %%
plt.figure(figsize=(10,6))
sns.countplot(titds['Pclass'])
print(titds['Pclass'].value_counts())
plt.show()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# as pe above plot we can see that maximum number of passengers is in 3 .

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Name'])
print(df['Name'].value_counts())
plt.show()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Sex'])
print(df['Sex'].value_counts())
plt.show()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# as per above plot here we can see the number of male passenger is higher then female passengers.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Age'])
print(df['Age'].value_counts())
plt.show()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %% [markdown]
# as per this plot we can see the maximum number of passenger is between the age of 20 to 40.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['SibSp'])
print(df['SibSp'].value_counts())
plt.show()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# in this plot we can see that maximum passenger is in 0 and minimum passenger is 5 .

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Parch'])
print(df['Parch'].value_counts())
plt.show()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# in this plot 0 is highest and 6 is lowest .

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Ticket'])
print(df['Ticket'].value_counts())
plt.show()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Fare'])
print(df['Fare'].value_counts())
plt.show()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %% [markdown]
# as per the plot we can see that fare can go up and down.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Embarked'])
print(df['Embarked'].value_counts())
plt.show()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# in this plot we can see S is highest and Q is lowest.

# %% [markdown]
# 2 . Bivariant Analysis

# %%
# comparision between survied and pclass

plt.figure(figsize=(10,6))
plt.title('Comparision between Survived and Pclass')
sns.stripplot(x='Survived',y='Pclass',data=titds,palette='deep')
plt.show()

# %% [markdown]
# in this plot we can see that Survived and Pclass is almost same .

# %%
# comparision between sex and age

plt.figure(figsize=(10,6))
plt.title('Comparision between Sex and Age')
sns.stripplot(x='Age',y='Sex',data=titds,palette='deep')
plt.show()

# %%
# comparision between age and sibsp

plt.figure(figsize=(10,6))
plt.title('Comparision between Age and SibSp')
sns.scatterplot(x='Age',y='SibSp',data=titds,palette='bright')
plt.show()

# %% [markdown]
# in this we can see that when sibSp is high there is very less age group passenger .

# %%
# compairsion btween Pclass and Ticket

plt.figure(figsize=(10,6))
plt.title('Comparision between Pclass and Ticket')
sns.scatterplot(x='Pclass',y='Ticket',data=titds,palette='bright')
plt.show()

# %%
# comparision between ticket and fare

plt.figure(figsize=(10,6))
plt.title('Comparision between Ticket and Fare')
sns.scatterplot(x='Ticket',y='Fare',data=titds,palette='deep')
plt.show()

# %% [markdown]
# we can see that fare and tickets are almost same and when fare increase there is very less tickets.

# %%
# comparision between fare and embarked

plt.figure(figsize=(10,6))
plt.title('Comparision between Fare and Embarked')
sns.scatterplot(x='Fare',y='Embarked',data=titds,palette='bright')
plt.show()

# %% [markdown]
# in the plot we can see that maximum embarked is between 0 to 100.

# %%
# checking embarked with sex
sns.catplot(x='Embarked',y='Sex',data=titds,palette='spring_r')

# checking embarked with embarked and Age
sns.catplot(x='Embarked',y='Age',data=titds,palette='spring_r')

#checking embarked with ticket
sns.catplot(x='Embarked',y='Ticket',data=titds,palette='spring_r')

# %% [markdown]
# in first plot we can see that embarked and sex is almost equal.

# %% [markdown]
# in second plot we can see that embarked and age at 2 is more compare to 0 and 1.

# %% [markdown]
# in third plot there is more tickets in 2 point.

# %%
# checking embarked in fare

sns.catplot(x='Fare',col='Embarked',data=titds,palette='icefire',kind='count')

# %% [markdown]
# as per above plot we can see that there is more fare in embarked 2.

# %%
# checking embarked in Pclass

sns.catplot(x='Pclass',col='Embarked',data=titds,palette='deep',kind='count')

# %% [markdown]
# as per above plot we can see there more Pclass in embarked 2 .

# %%
# checking embarked with survived

sns.catplot(x='Survived',col='Embarked',data=titds,palette='icefire',kind='count')

# %% [markdown]
# in this plot higher number of passenger servived in embarked 2 .

# %%
# checking embraked in parch

sns.catplot(x='Parch',hue='Embarked',data=titds,palette='cividis',kind='count')

# %% [markdown]
# in this plot we can see that parch is higher for embarked 2 .

# %% [markdown]
# 3. Multivariate Analysis

# %%
sns.pairplot(data=titds , hue='Embarked' , palette='deep')

# %% [markdown]
# 1.The pairplot is a pairwise relation between the columns on basis of 'Embarked'.

# %% [markdown]
# # Checking Outliers

# %% [markdown]
# here will check outliers using box plot.

# %%
titds.plot(kind='box' , subplots=True , layout=(2,6) , figsize=(10,10))
# Out:
# PassengerId       AxesSubplot(0.125,0.53;0.110714x0.35)
# Survived       AxesSubplot(0.257857,0.53;0.110714x0.35)
# Pclass         AxesSubplot(0.390714,0.53;0.110714x0.35)
# Name           AxesSubplot(0.523571,0.53;0.110714x0.35)
# Sex            AxesSubplot(0.656429,0.53;0.110714x0.35)
# Age            AxesSubplot(0.789286,0.53;0.110714x0.35)
# SibSp             AxesSubplot(0.125,0.11;0.110714x0.35)
# Parch          AxesSubplot(0.257857,0.11;0.110714x0.35)
# Ticket         AxesSubplot(0.390714,0.11;0.110714x0.35)
# Fare           AxesSubplot(0.523571,0.11;0.110714x0.35)
# Embarked       AxesSubplot(0.656429,0.11;0.110714x0.35)
# dtype: object

# %% [markdown]
# here we can see there is some outliers in columns age,SibSp,Parch,Fare.

# %% [markdown]
# # Removing Outlier

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(titds))
z
# Out:
#      PassengerId  Survived    Pclass      Name       Sex       Age     SibSp  \
# 0       1.730108  0.789272  0.827377  1.310217  0.737695  0.592481  0.432793
# 1       1.726220  1.266990  1.566107  0.991410  1.355574  0.638789  0.432793
# 2       1.722332  1.266990  0.827377  0.357685  1.355574  0.284663  0.474545
# 3       1.718444  1.266990  1.566107  0.672604  1.355574  0.407926  0.432793
# 4       1.714556  0.789272  0.827377  1.671790  0.737695  0.407926  0.474545
# ..           ...       ...       ...       ...       ...       ...       ...
# 886     1.714556  0.789272  0.369365  0.400452  0.737695  0.207709  0.474545
# 887     1.718444  1.266990  1.566107  0.552079  1.355574  0.823344  0.474545
# 888     1.722332  0.789272  0.827377  0.124412  1.355574  0.000000  0.432793
# 889     1.726220  1.266990  1.566107  1.415189  0.737695  0.284663  0.474545
# 890     1.730108  0.789272  0.827377  0.874774  0.737695  0.177063  0.474545
#
#         Parch    Ticket      Fare  Embarked
# ...

# %% [markdown]
# # Checking for Skewness

# %%
titds.skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Name           0.000000
# Sex           -0.618921
# Age            0.434488
# SibSp          3.695352
# Parch          2.749117
# Ticket         0.000246
# Fare           4.787317
# Embarked      -1.264823
# dtype: float64

# %% [markdown]
# we can see that there is some skewness present .

# %%
# removing skewness

titds = np.cbrt(titds)
titds.skew()
# Out:
# PassengerId   -0.851328
# Survived       0.478523
# Pclass        -0.776838
# Name          -0.882091
# Sex           -0.618921
# Age           -1.375431
# SibSp          1.033059
# Parch          1.348334
# Ticket        -0.888353
# Fare           1.230382
# Embarked      -1.520662
# dtype: float64

# %% [markdown]
# now the skewness is almost removed.

# %% [markdown]
# # Checking Multicollinearity

# %%
plt.figure(figsize=(10,6))
sns.heatmap(titds_corr , annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# as per the above heatmap we can see that there is some collinearity present.

# %%
# assigning x and y values

x1 = titds.iloc[:,:-1]
y = titds.iloc[:,-1]

# %%
x1.shape
# Out:
# (891, 10)

# %%
# now we need only columns from x to work on multicollinearity , where rows=0 and columns=1

x1.shape[1]
# Out:
# 10

# %%
y
# Out:
# 0      1.259921
# 1      0.000000
# 2      1.259921
# 3      1.259921
# 4      1.259921
#          ...
# 886    1.259921
# 887    1.259921
# 888    1.259921
# 889    0.000000
# 890    1.000000
# Name: Embarked, Length: 891, dtype: float64

# %% [markdown]
# # Use of VIF for Multicollinearity

# %%
import statsmodels.api as sm
from scipy import stats

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def cal_vif(x1):
    vif = pd.DataFrame()
    vif['Variables'] = x1.columns
    vif['VIF factor'] = [variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
    return(vif)

cal_vif(x1)
# Out:
#      Variables  VIF factor
# 0  PassengerId   15.478857
# 1     Survived    2.428216
# 2       Pclass   46.552080
# 3         Name   15.548864
# 4          Sex    4.099430
# 5          Age   30.222276
# 6        SibSp    2.080281
# 7        Parch    2.045442
# 8       Ticket   19.428213
# 9         Fare   12.503469

# %% [markdown]
# pclass and age is highly correlated .so we will drop it.

# %%
x1 = titds.drop(['Pclass'],axis=1)

# %%
cal_vif(x1)
# Out:
#      Variables  VIF factor
# 0  PassengerId   14.112065
# 1     Survived    2.386421
# 2         Name   14.172579
# 3          Sex    3.998687
# 4          Age   26.850413
# 5        SibSp    2.031763
# 6        Parch    1.968082
# 7       Ticket   12.321705
# 8         Fare   11.243410
# 9     Embarked    5.275172

# %%
x=x1

# %% [markdown]
# now we will do train_test_split method.

# %% [markdown]
# # Performing Train_test_split Method

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train, y_test = train_test_split(x,y,test_size=.30 ,random_state=45)

# %%
x_train.shape
# Out:
# (623, 10)

# %%
x_test.shape
# Out:
# (268, 10)

# %%
y_train.shape
# Out:
# (623,)

# %%
y_test.shape
# Out:
# (268,)

# %% [markdown]
# # Applying Models

# %%
import sklearn
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score, mean_squared_error , mean_absolute_error

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
pred_lr = lr.predict(x_test)
print('Linear Regression')

print('r2 score :',r2_score(y_test,pred_lr))
print('mean squared error :',mean_squared_error(y_test,pred_lr))
print('mean absolute error:',mean_absolute_error(y_test,pred_lr))
print('square root error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Linear Regression
# r2 score : 1.0
# mean squared error : 1.5220593550736543e-31
# mean absolute error: 2.8217550583649618e-16
# square root error: 3.901357911129988e-16

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
print('Decision Tree Regressor')

print('r2 score:',r2_score(y_test,pred_dtr))
print('mean sqaured error:',mean_squared_error(y_test,pred_dtr))
print('mean absolute error:',mean_absolute_error(y_test,pred_dtr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# Decision Tree Regressor
# r2 score: 1.0
# mean sqaured error: 4.061971371949126e-29
# mean absolute error: 5.380439046205796e-15
# squared root error: 6.37335968853879e-15

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred_svr = svr.predict(x_test)
print('Support Vector Regressor')

print('r2 score:',r2_score(y_test,pred_svr))
print('mean sqaured error:',mean_squared_error(y_test,pred_svr))
print('mean absolute error:',mean_absolute_error(y_test,pred_svr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# Support Vector Regressor
# r2 score: 0.9628002645032896
# mean sqaured error: 0.008592334929686574
# mean absolute error: 0.08909520078314039
# squared root error: 0.09269484845279469

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
pred_knr = knr.predict(x_test)
print('KNeighbors Regressor')

print('r2 score :',r2_score(y_test,pred_knr))
print('mean squared error:',mean_squared_error(y_test,pred_knr))
print('mean absolute error:',mean_absolute_error(y_test,pred_knr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_knr)))
# Out:
# KNeighbors Regressor
# r2 score : 0.6706734687116911
# mean squared error: 0.07606731123965332
# mean absolute error: 0.15517659012603166
# squared root error: 0.27580302978693566

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr = rfr.predict(x_test)
print('Random Forest Regressor')

print('r2 score:',r2_score(y_test,pred_rfr))
print('mean squared error:',mean_squared_error(y_test,pred_rfr))
print('mean absolute error:',mean_absolute_error(y_test,pred_rfr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_knr)))
# Out:
# Random Forest Regressor
# r2 score: 1.0
# mean squared error: 1.264973783651977e-30
# mean absolute error: 9.494892434480815e-16
# squared root error: 0.27580302978693566

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
pred_ls = ls.predict(x_test)
print('Lasso Regressor')

print('r2 score:',r2_score(y_test,pred_ls))
print('mean sqaure error:',mean_squared_error(y_test,pred_ls))
print('mean absolute error:',mean_absolute_error(y_test,pred_ls))
print('sqaured root error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Lasso Regressor
# r2 score: 0.9999998268854366
# mean sqaure error: 3.998572273814029e-08
# mean absolute error: 0.00015345386758021447
# sqaured root error: 0.00019996430365977897

# %%
from sklearn.linear_model import Ridge

# %%
rd = Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
print('Ridge Regressor')

print('r2 score:',r2_score(y_test,pred_rd))
print('mean squared error:',mean_squared_error(y_test,pred_rd))
print('mean absolute error:',mean_absolute_error(y_test,pred_rd))
print('sqaured root error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge Regressor
# r2 score: 0.999999999999439
# mean squared error: 1.2957300485391125e-13
# mean absolute error: 2.689556502308257e-07
# sqaured root error: 3.599625047889172e-07

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr = gbr.predict(x_test)
print('Gradient Boosting Regressor')

print('r2 score:',r2_score(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('mean absolute error:',mean_absolute_error(y_test,pred_gbr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# Gradient Boosting Regressor
# r2 score: 0.9999999992944528
# mean squared error: 1.6296616068177473e-10
# mean absolute error: 9.796570780100698e-06
# squared root error: 1.2765820016034016e-05

# %%
from sklearn.ensemble import BaggingRegressor

# %%
br = BaggingRegressor()
br.fit(x_train,y_train)
pred_br = br.predict(x_test)
print('Bagging Regressor')

print('r2 score',r2_score(y_test,pred_br))
print('mean squared error:',mean_squared_error(y_test,pred_br))
print('mean absolute error:',mean_absolute_error(y_test,pred_br))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_br)))
# Out:
# Bagging Regressor
# r2 score 1.0
# mean squared error: 8.995369128191836e-30
# mean absolute error: 2.531971315861551e-15
# squared root error: 2.9992280887241366e-15

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(lr ,x,y,cv=5)
print('score1:',score1)
print('score1 mean:',score1.mean())
print('score1 std:',score1.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_lr)-score1.mean())*100)
# Out:
# score1: [1. 1. 1. 1. 1.]
# score1 mean: 1.0
# score1 std: 0.0
# Difference between r2 score and mean: 0.0

# %%
score2 = cross_val_score(dtr,x,y,cv=5)
print('score2:',score2)
print('score2 mean:',score2.mean())
print('score2 std:',score2.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_dtr)-score2.mean())*100)
# Out:
# score2: [1. 1. 1. 1. 1.]
# score2 mean: 1.0
# score2 std: 0.0
# Differnce between r2 score and mean: 0.0

# %%
score3 = cross_val_score(svr,x,y,cv=5)
print('score3:',score3)
print('score3 mean:',score3.mean())
print('score3 std:',score3.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_svr)-score3.mean())*100)
# Out:
# score3: [0.93235141 0.96531518 0.97319734 0.97145367 0.94557013]
# score3 mean: 0.9575775465750425
# score3 std: 0.01598081103149984
# Differnce between r2 score and mean: 0.5222717928247134

# %%
score4 = cross_val_score(knr,x,y,cv=5)
print('score4:',score4)
print('score4 mean:',score4.mean())
print('score4 std:',score4.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_knr)-score4.mean())*100)
# Out:
# score4: [0.38700469 0.56269591 0.66806351 0.71811143 0.67010841]
# score4 mean: 0.6011967892047945
# score4 std: 0.11853233847786884
# Differnce between r2 score and mean: 6.947667950689662

# %%
score5 = cross_val_score(rfr,x,y,cv=5)
print('score5:',score5)
print('score5 mean:',score5.mean())
print('score5 std:',score5.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_rfr)-score5.mean())*100)
# Out:
# score5: [1. 1. 1. 1. 1.]
# score5 mean: 1.0
# score5 std: 0.0
# Differnce between r2 score and mean: 0.0

# %%
score6 = cross_val_score(ls,x,y,cv=5)
print('score6:',score6)
print('score6 mean:',score6.mean())
print('score6 std:',score6.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_ls)-score6.mean())*100)
# Out:
# score6: [0.99999982 0.99999983 0.99999982 0.99999981 0.99999983]
# score6 mean: 0.9999998222110731
# score6 std: 5.387839130936593e-09
# Differnce between r2 score and mean: 4.6743635628843094e-07

# %%
score7 = cross_val_score(rd,x,y,cv=5)
print('score7:',score7)
print('score7 mean:',score7.mean())
print('score7 std:',score7.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_rd)-score7.mean())*100)
# Out:
# score7: [1. 1. 1. 1. 1.]
# score7 mean: 0.9999999999996074
# score7 std: 2.5946745808255838e-14
# Differnce between r2 score and mean: -1.6842083283563625e-11

# %%
score8 = cross_val_score(gbr,x,y,cv=5)
print('score8:',score8)
print('score8 mean:',score8.mean())
print('score8 std:',score8.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_gbr)-score8.mean())*100)
# Out:
# score8: [1. 1. 1. 1. 1.]
# score8 mean: 0.9999999992928845
# score8 std: 1.8777491276473734e-12
# Differnce between r2 score and mean: 1.568301044585496e-10

# %%
score9 = cross_val_score(br,x,y,cv=5)
print('score9:',score9)
print('score9 mean:',score9.mean())
print('score9 std:',score9.std())
print('Differnce between r2 score and mean:',(r2_score(y_test,pred_br)-score9.mean())*100)
# Out:
# score9: [1. 1. 1. 1. 1.]
# score9 mean: 1.0
# score9 std: 0.0
# Differnce between r2 score and mean: 0.0

# %% [markdown]
# as per the above result the Ridge Regressor has the lowest difference between r2 score and mean . So its best fitting model for prediction.

# %% [markdown]
# # Finalizing the model

# %%
final_model = Ridge(alpha=0.01)
final_model.fit(x_train,y_train)
pred = final_model.predict(x_test)
print(pred)
# Out:
# [1.25990269e+00 1.25991252e+00 1.25990469e+00 1.25988880e+00
#  1.25990847e+00 1.25989173e+00 1.25990726e+00 1.25990827e+00
#  1.25990868e+00 1.25990643e+00 1.25990455e+00 1.25990481e+00
#  1.25989814e+00 1.25990238e+00 1.25990542e+00 1.25991630e+00
#  1.25990375e+00 1.25990749e+00 1.25989650e+00 1.25989214e+00
#  1.25990372e+00 1.00000523e+00 1.25990686e+00 1.25987643e+00
#  1.25990363e+00 1.25989910e+00 1.25990497e+00 8.47834664e-05
#  1.25990002e+00 1.25990445e+00 9.78256052e-05 1.25990543e+00
#  1.25990038e+00 1.25990113e+00 1.25987636e+00 1.25991674e+00
#  7.74817890e-05 1.25985633e+00 1.25991318e+00 1.25988210e+00
#  1.25990532e+00 1.00001117e+00 9.99994870e-01 1.25990379e+00
#  1.25990573e+00 1.25990596e+00 6.42751191e-05 1.25990535e+00
#  3.69591947e-05 1.25989723e+00 1.00000202e+00 1.25990424e+00
#  1.25989550e+00 1.25989756e+00 1.25990738e+00 1.25991089e+00
#  6.12523505e-05 1.25989426e+00 7.43699477e-05 1.00000500e+00
# ...

# %% [markdown]
# # Saving Best Model

# %%
# saving best model using .pkl

import joblib
joblib.dump(final_model,'Titanic_Survived.pkl')
# Out:
# ['Titanic_Survived.pkl']

# %%
# Predicting the saved model

model = joblib.load('Titanic_Survived.pkl')

# Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([1.25990269e+00, 1.25991252e+00, 1.25990469e+00, 1.25988880e+00,
#        1.25990847e+00, 1.25989173e+00, 1.25990726e+00, 1.25990827e+00,
#        1.25990868e+00, 1.25990643e+00, 1.25990455e+00, 1.25990481e+00,
#        1.25989814e+00, 1.25990238e+00, 1.25990542e+00, 1.25991630e+00,
#        1.25990375e+00, 1.25990749e+00, 1.25989650e+00, 1.25989214e+00,
#        1.25990372e+00, 1.00000523e+00, 1.25990686e+00, 1.25987643e+00,
#        1.25990363e+00, 1.25989910e+00, 1.25990497e+00, 8.47834664e-05,
#        1.25990002e+00, 1.25990445e+00, 9.78256052e-05, 1.25990543e+00,
#        1.25990038e+00, 1.25990113e+00, 1.25987636e+00, 1.25991674e+00,
#        7.74817890e-05, 1.25985633e+00, 1.25991318e+00, 1.25988210e+00,
#        1.25990532e+00, 1.00001117e+00, 9.99994870e-01, 1.25990379e+00,
#        1.25990573e+00, 1.25990596e+00, 6.42751191e-05, 1.25990535e+00,
#        3.69591947e-05, 1.25989723e+00, 1.00000202e+00, 1.25990424e+00,
# ...

# %% [markdown]
# # Checking the Predicted model is correct result

# %%
a = np.array(y_test)
titds = pd.DataFrame()
titds['predicted'] = prediction
titds['original'] = a
titds
# Out:
#      predicted  original
# 0     1.259903  1.259921
# 1     1.259913  1.259921
# 2     1.259905  1.259921
# 3     1.259889  1.259921
# 4     1.259908  1.259921
# ..         ...       ...
# 263   1.259909  1.259921
# 264   1.259938  1.259921
# 265   1.259932  1.259921
# 266   1.259908  1.259921
# 267   1.259890  1.259921
#
# [268 rows x 2 columns]

# %% [markdown]
# as per above data predicted and original data is equal.
